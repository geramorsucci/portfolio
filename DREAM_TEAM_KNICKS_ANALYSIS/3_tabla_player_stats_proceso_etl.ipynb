# %% [markdown]
# # PROYECTO FINAL
#
# ##### Ejecutamos tecnicas de ETL de 4 dataframe que se usaran para completar el análisis sobre los jugadores que contienen los datos específicos de la temporada (2021-2022-2023) de cada jugador (puntos, bloqueos, asistencias, salarios, entre otros).

# %% [markdown]
# Se importan las librerias que se consideraron para realizar el ETL en esta fase del proyecto

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ANALISIS DE LA TEMPORADA 2021
#
# Carga del dataframe "nba2021PerGame"
#
# Revision del dataframe (info, conteo y nulos)

# %%
df1 = pd.read_csv("nba2021_per_game.csv")

# %%
# Primeras filas del dataframe
print(df1.head(11))
# Out:
#                       Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0           Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590
# 1               Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125
# 2               Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603
# 3                Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573
# 4          LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476
# 5          Ty-Shon Alexander  SG   22  PHO   3   0   2.7  0.0   1.0  0.000
# 6   Nickeil Alexander-Walker  SG   22  NOP  23   3  19.2  3.3   8.2  0.410
# 7              Grayson Allen  SG   25  MEM  19   8  23.9  3.2   7.4  0.429
# 8              Jarrett Allen   C   22  TOT  28  10  26.2  4.4   6.8  0.642
# 9              Jarrett Allen   C   22  BRK  12   5  26.7  3.7   5.4  0.677
# 10             Jarrett Allen   C   22  CLE  16   5  25.9  4.9   7.8  0.624
#
#     ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...  0.561  1.3  2.7   4.0  0.6  0.4  0.5  1.0  1.9   6.5
# 1   ...  0.000  0.0  0.5   0.5  0.3  0.0  0.0  0.0  0.2   0.3
# 2   ...  0.468  4.3  4.6   8.9  2.1  1.0  0.6  1.7  1.9   8.0
# 3   ...  0.841  1.9  7.3   9.2  5.3  1.0  1.0  3.0  2.6  19.9
# 4   ...  0.762  0.8  3.5   4.3  1.9  0.4  0.9  0.9  1.5  14.1
# 5   ...  0.000  0.0  0.3   0.3  0.3  0.0  0.0  0.0  0.3   0.0
# 6   ...  0.781  0.2  2.4   2.7  2.0  1.1  0.3  1.3  1.7   8.8
# 7   ...  0.892  0.4  2.5   2.9  2.1  1.0  0.2  1.1  1.3  10.4
# 8   ...  0.758  2.9  6.1   9.0  1.6  0.5  1.6  1.5  1.6  12.3
# 9   ...  0.754  3.2  7.3  10.4  1.7  0.6  1.6  1.8  1.8  11.2
# 10  ...  0.761  2.8  5.2   7.9  1.6  0.4  1.7  1.3  1.4  13.2
#
# [11 rows x 29 columns]

# %%
# Información general sobre el dataframe
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  497 non-null    object
#  1   Pos     497 non-null    object
#  2   Age     497 non-null    int64
#  3   Tm      497 non-null    object
#  4   G       497 non-null    int64
#  5   GS      497 non-null    int64
#  6   MP      497 non-null    float64
#  7   FG      497 non-null    float64
#  8   FGA     497 non-null    float64
#  9   FG%     497 non-null    float64
#  10  3P      497 non-null    float64
#  11  3PA     497 non-null    float64
#  12  3P%     497 non-null    float64
#  13  2P      497 non-null    float64
#  14  2PA     497 non-null    float64
#  15  2P%     497 non-null    float64
#  16  eFG%    497 non-null    float64
#  17  FT      497 non-null    float64
#  18  FTA     497 non-null    float64
#  19  FT%     497 non-null    float64
#  20  ORB     497 non-null    float64
#  21  DRB     497 non-null    float64
#  22  TRB     497 non-null    float64
#  23  AST     497 non-null    float64
#  24  STL     497 non-null    float64
#  25  BLK     497 non-null    float64
#  26  TOV     497 non-null    float64
#  27  PF      497 non-null    float64
#  28  PTS     497 non-null    float64
# dtypes: float64(23), int64(3), object(3)
# memory usage: 112.7+ KB
# None

# %%
np.shape(df1)
# Out:
# (497, 29)

# %%
#Revision Nulos 
ValoresNull1 = df1.isnull().sum() [df1.isnull().sum()>0]
print(ValoresNull1)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# CAMBIAR NOMBRE DE COLUMNAS
#
# Se realiza modificacion de nombres de columnas para unificar criterios con el resto de las tablas

# %%
nuevos_nombres = {
    'Tm': 'Team',
    'G': 'GP'
}

#Renombrar las columnas especificadas
df1.rename(columns=nuevos_nombres, inplace=True)

print(df1.head())
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0   Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...
# 1       Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...
# 2       Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...
# 3        Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...
# 4  LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.561  1.3  2.7  4.0  0.6  0.4  0.5  1.0  1.9   6.5
# 1  0.000  0.0  0.5  0.5  0.3  0.0  0.0  0.0  0.2   0.3
# 2  0.468  4.3  4.6  8.9  2.1  1.0  0.6  1.7  1.9   8.0
# 3  0.841  1.9  7.3  9.2  5.3  1.0  1.0  3.0  2.6  19.9
# 4  0.762  0.8  3.5  4.3  1.9  0.4  0.9  0.9  1.5  14.1
#
# [5 rows x 29 columns]

# %%
# Año que deseas agregar
Temporada = 2021

# Agregar una nueva columna 'Temporada' con el valor del año especificado
df1['Temp'] = Temporada

# Mostrar las primeras filas del DataFrame para verificar
print(df1.head())
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0   Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...  1.3
# 1       Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...  0.0
# 2       Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...  4.3
# 3        Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...  1.9
# 4  LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...  0.8
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0  2.7  4.0  0.6  0.4  0.5  1.0  1.9   6.5  2021
# 1  0.5  0.5  0.3  0.0  0.0  0.0  0.2   0.3  2021
# 2  4.6  8.9  2.1  1.0  0.6  1.7  1.9   8.0  2021
# 3  7.3  9.2  5.3  1.0  1.0  3.0  2.6  19.9  2021
# 4  3.5  4.3  1.9  0.4  0.9  0.9  1.5  14.1  2021
#
# [5 rows x 30 columns]

# %%
print(df1.head())
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0   Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...  1.3
# 1       Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...  0.0
# 2       Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...  4.3
# 3        Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...  1.9
# 4  LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...  0.8
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0  2.7  4.0  0.6  0.4  0.5  1.0  1.9   6.5  2021
# 1  0.5  0.5  0.3  0.0  0.0  0.0  0.2   0.3  2021
# 2  4.6  8.9  2.1  1.0  0.6  1.7  1.9   8.0  2021
# 3  7.3  9.2  5.3  1.0  1.0  3.0  2.6  19.9  2021
# 4  3.5  4.3  1.9  0.4  0.9  0.9  1.5  14.1  2021
#
# [5 rows x 30 columns]

# %%
np.shape(df1)
# Out:
# (497, 30)

# %%
# Obtener los valores únicos de la columna team_abbreviation
valores_unicos = df1['Team'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['MIA' 'MIL' 'NOP' 'SAS' 'PHO' 'MEM' 'TOT' 'BRK' 'CLE' 'ORL' 'LAL' 'POR'
#  'TOR' 'CHI' 'WAS' 'UTA' 'SAC' 'CHO' 'NYK' 'DEN' 'LAC' 'GSW' 'OKC' 'MIN'
#  'DET' 'DAL' 'IND' 'ATL' 'PHI' 'BOS' 'HOU']

# %%
# Suponiendo que ya tienes el DataFrame 'df1'
# Obtener los índices de las filas donde 'Team' es 'TOT'
indices_a_eliminar = df1[df1['Team'] == 'TOT'].index

# Eliminar las filas con los índices especificados
df1_cleaned = df1.drop(index=indices_a_eliminar)

# Mostrar el DataFrame resultante
print("DataFrame después de eliminar filas donde 'Team' es 'TOT':")
print(df1_cleaned)
# Out:
# DataFrame después de eliminar filas donde 'Team' es 'TOT':
#                 Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...
# 1         Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...
# 2         Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...
# 3          Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...
# 4    LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 492       Delon Wright  SG   28  DET  28  23  29.4  3.7   8.1  0.456  ...
# 493     Thaddeus Young  PF   32  CHI  23   0  25.7  5.1   8.7  0.587  ...
# 494         Trae Young  PG   22  ATL  26  26  34.7  7.6  17.7  0.429  ...
# 495        Cody Zeller   C   28  CHO  15  12  24.1  4.2   8.0  0.525  ...
# 496        Ivica Zubac   C   23  LAC  30   1  19.5  3.2   4.7  0.669  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0    1.3  2.7  4.0  0.6  0.4  0.5  1.0  1.9   6.5  2021
# 1    0.0  0.5  0.5  0.3  0.0  0.0  0.0  0.2   0.3  2021
# 2    4.3  4.6  8.9  2.1  1.0  0.6  1.7  1.9   8.0  2021
# 3    1.9  7.3  9.2  5.3  1.0  1.0  3.0  2.6  19.9  2021
# 4    0.8  3.5  4.3  1.9  0.4  0.9  0.9  1.5  14.1  2021
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 492  1.1  3.5  4.6  4.9  1.4  0.5  1.2  1.1  10.5  2021
# 493  2.4  3.4  5.8  4.4  1.4  0.5  2.0  2.9  11.2  2021
# 494  0.7  3.2  3.8  9.3  0.8  0.3  4.3  2.0  26.5  2021
# 495  2.6  5.4  8.0  2.5  0.7  0.6  0.9  2.5  10.1  2021
# 496  2.3  4.4  6.6  1.1  0.4  0.8  1.0  2.6   8.3  2021
#
# [489 rows x 30 columns]

# %%
np.shape(df1_cleaned)
# Out:
# (489, 30)

# %% [markdown]
# Ya tenemos limpio el dataset de la temporada 2020-2021. Lo guardaremos para más adelante, cuando hagamos el merge de las temporadas.

# %%
df1_cleaned.to_csv("Temporada2020_2021.csv",sep=",")

# %% [markdown]
# # ANALISIS TEMPORADA 2021 - 2022

# %%
# importación de los datos.
df2 = pd.read_csv("NBAPlayerStatsRegular.csv", encoding='latin-1', delimiter=';')

# %%
print(df2.head(11))
# Out:
#     Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0    1          Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1    2              Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2    3               Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3    4              Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4    5         LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# 5    6  Nickeil Alexander-Walker  SG   23  TOT  65  21  22.6  3.9  10.5  ...
# 6    6  Nickeil Alexander-Walker  SG   23  NOP  50  19  26.3  4.7  12.6  ...
# 7    6  Nickeil Alexander-Walker  SG   23  UTA  15   2   9.9  1.1   3.2  ...
# 8    7             Grayson Allen  SG   26  MIL  66  61  27.3  3.9   8.6  ...
# 9    8             Jarrett Allen   C   23  CLE  56  56  32.3  6.6   9.7  ...
# 10   9             Jose Alvarado  PG   23  NOP  54   1  15.4  2.4   5.4  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   0.595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1   0.543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2   0.753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3   0.625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4   0.873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# 5   0.743  0.6  2.3   2.9  2.4  0.7  0.4  1.4  1.6  10.6
# 6   0.722  0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.8  12.8
# 7   0.917  0.1  1.5   1.5  1.1  0.3  0.3  0.5  1.0   3.5
# 8   0.865  0.5  2.9   3.4  1.5  0.7  0.3  0.7  1.5  11.1
# 9   0.708  3.4  7.3  10.8  1.6  0.8  1.3  1.7  1.7  16.1
# 10  0.679  0.5  1.4   1.9  2.8  1.3  0.1  0.7  1.4   6.1
#
# [11 rows x 30 columns]

# %%
# Información general sobre el dataframe
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      812 non-null    int64
#  1   Player  812 non-null    object
#  2   Pos     812 non-null    object
#  3   Age     812 non-null    int64
#  4   Tm      812 non-null    object
#  5   G       812 non-null    int64
#  6   GS      812 non-null    int64
#  7   MP      812 non-null    float64
#  8   FG      812 non-null    float64
#  9   FGA     812 non-null    float64
#  10  FG%     812 non-null    float64
#  11  3P      812 non-null    float64
#  12  3PA     812 non-null    float64
#  13  3P%     812 non-null    float64
#  14  2P      812 non-null    float64
#  15  2PA     812 non-null    float64
#  16  2P%     812 non-null    float64
#  17  eFG%    812 non-null    float64
#  18  FT      812 non-null    float64
#  19  FTA     812 non-null    float64
#  20  FT%     812 non-null    float64
#  21  ORB     812 non-null    float64
#  22  DRB     812 non-null    float64
#  23  TRB     812 non-null    float64
#  24  AST     812 non-null    float64
#  25  STL     812 non-null    float64
#  26  BLK     812 non-null    float64
#  27  TOV     812 non-null    float64
#  28  PF      812 non-null    float64
#  29  PTS     812 non-null    float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 190.4+ KB

# %%
np.shape(df2)
# Out:
# (812, 30)

# %%
# consulta de valores nulos
ValoresNull2 = df2.isnull().sum() [df2.isnull().sum()>0]
print(ValoresNull2)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Revisando cantidad de veces que se repite un nombre.

# %%
conteo_unicos = df2["Player"].value_counts()
print(conteo_unicos)
# Out:
# Player
# Greg Monroe            5
# Danuel House Jr.       4
# Wenyen Gabriel         4
# James Ennis III        4
# Juancho Hernangómez    4
#                       ..
# Eric Bledsoe           1
# Trae Young             1
# Omer Yurtseven         1
# Cody Zeller            1
# Precious Achiuwa       1
# Name: count, Length: 605, dtype: int64

# %%
# Año que deseas agregar
Temporada2 = 2022

# Agregar una nueva columna 'Temporada' con el valor del año especificado
df2['Temp'] = Temporada2

# Mostrar las primeras filas del DataFrame para verificar
print(df2.head())
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0   1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  2.0
# 1   2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  4.6
# 2   3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  2.4
# 3   4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  1.0
# 4   5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  1.6
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1  2022
# 1  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9  2022
# 2  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1  2022
# 3  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1  2022
# 4  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9  2022
#
# [5 rows x 31 columns]

# %%
df_filtered = df2

# %% [markdown]
# Ahora notamos que ya quedo resuelto el tema de la columna TOTAL TEAM

# %%
df_filtered.head(20)
# Out:
#     Rk                    Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1          Precious Achiuwa   C   22  TOR  73  28  23.6   3.6   8.3  ...
# 1    2              Steven Adams   C   28  MEM  76  75  26.3   2.8   5.1  ...
# 2    3               Bam Adebayo   C   24  MIA  56  56  32.6   7.3  13.0  ...
# 3    4              Santi Aldama  PF   21  MEM  32   0  11.3   1.7   4.1  ...
# 4    5         LaMarcus Aldridge   C   36  BRK  47  12  22.3   5.4   9.7  ...
# 5    6  Nickeil Alexander-Walker  SG   23  TOT  65  21  22.6   3.9  10.5  ...
# 6    6  Nickeil Alexander-Walker  SG   23  NOP  50  19  26.3   4.7  12.6  ...
# 7    6  Nickeil Alexander-Walker  SG   23  UTA  15   2   9.9   1.1   3.2  ...
# 8    7             Grayson Allen  SG   26  MIL  66  61  27.3   3.9   8.6  ...
# 9    8             Jarrett Allen   C   23  CLE  56  56  32.3   6.6   9.7  ...
# 10   9             Jose Alvarado  PG   23  NOP  54   1  15.4   2.4   5.4  ...
# 11  10           Justin Anderson  SF   28  TOT  16   6  19.8   2.3   5.9  ...
# 12  10           Justin Anderson  SF   28  CLE   3   0  15.7   1.3   2.7  ...
# 13  10           Justin Anderson  SF   28  IND  13   6  20.7   2.5   6.7  ...
# 14  11             Kyle Anderson  PF   28  MEM  69  11  21.5   3.0   6.8  ...
# 15  12     Giannis Antetokounmpo  PF   27  MIL  67  67  32.9  10.3  18.6  ...
# 16  13    Thanasis Antetokounmpo  SF   29  MIL  48   6   9.9   1.5   2.7  ...
# 17  14           Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  ...
# 18  15              Cole Anthony  PG   21  ORL  65  65  31.7   5.5  14.0  ...
# 19  16                OG Anunoby  SF   24  TOR  48  48  36.0   6.4  14.5  ...
#
#     ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0   2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1  2022
# 1   4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9  2022
# 2   2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1  2022
# 3   1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1  2022
# 4   1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9  2022
# 5   0.6  2.3   2.9  2.4  0.7  0.4  1.4  1.6  10.6  2022
# 6   0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.8  12.8  2022
# 7   0.1  1.5   1.5  1.1  0.3  0.3  0.5  1.0   3.5  2022
# 8   0.5  2.9   3.4  1.5  0.7  0.3  0.7  1.5  11.1  2022
# 9   3.4  7.3  10.8  1.6  0.8  1.3  1.7  1.7  16.1  2022
# 10  0.5  1.4   1.9  2.8  1.3  0.1  0.7  1.4   6.1  2022
# 11  0.3  2.6   2.9  2.1  0.5  0.4  0.5  1.4   6.4  2022
# 12  0.0  2.0   2.0  2.0  0.3  0.0  0.7  1.3   4.3  2022
# 13  0.3  2.8   3.1  2.1  0.5  0.5  0.5  1.4   6.8  2022
# 14  1.0  4.3   5.3  2.7  1.1  0.7  1.0  1.6   7.6  2022
# 15  2.0  9.6  11.6  5.8  1.1  1.4  3.3  3.2  29.9  2022
# 16  0.8  1.3   2.1  0.5  0.3  0.3  0.5  1.4   3.6  2022
# 17  0.9  3.3   4.2  1.0  0.7  0.8  0.9  2.4  13.3  2022
# 18  0.5  4.9   5.4  5.7  0.7  0.3  2.6  2.6  16.3  2022
# 19  1.5  4.0   5.5  2.6  1.5  0.5  1.7  2.7  17.1  2022
#
# [20 rows x 31 columns]

# %% [markdown]
# Consultamos si ahora los nombres se repiten

# %%
conteo_unicos = df_filtered["Player"].value_counts()
print(conteo_unicos)
# Out:
# Player
# Greg Monroe            5
# Danuel House Jr.       4
# Wenyen Gabriel         4
# James Ennis III        4
# Juancho Hernangómez    4
#                       ..
# Eric Bledsoe           1
# Trae Young             1
# Omer Yurtseven         1
# Cody Zeller            1
# Precious Achiuwa       1
# Name: count, Length: 605, dtype: int64

# %%
np.shape(df_filtered)
# Out:
# (812, 31)

# %% [markdown]
# Dropeamos la columna de los indices, porque son incorrectos.

# %%
df_filtered = df_filtered.drop(columns=['Rk'])

# %%
nuevos_nombres = {
    'Tm': 'Team',
    'G': 'GP'
}

# Renombrar las columnas especificadas
df_filtered.rename(columns=nuevos_nombres, inplace=True)


# Mostrar las primeras filas del DataFrame para verificar los cambios
print(df_filtered.head())
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...  2.0
# 1       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...  4.6
# 2        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...  2.4
# 3       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...  1.0
# 4  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...  1.6
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1  2022
# 1  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9  2022
# 2  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1  2022
# 3  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1  2022
# 4  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9  2022
#
# [5 rows x 30 columns]

# %%
# Obtener los valores únicos de la columna team_abbreviation
valores_unicos = df_filtered['Team'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['TOR' 'MEM' 'MIA' 'BRK' 'TOT' 'NOP' 'UTA' 'MIL' 'CLE' 'IND' 'LAL' 'ORL'
#  'NYK' 'HOU' 'WAS' 'PHO' 'SAC' 'DET' 'CHO' 'CHI' 'ATL' 'DEN' 'PHI' 'SAS'
#  'LAC' 'OKC' 'MIN' 'DAL' 'GSW' 'POR' 'BOS']

# %% [markdown]
# Se elimino donde en Team era TOT

# %%
# Suponiendo que ya tienes el DataFrame 'df1'
# Obtener los índices de las filas donde 'Team' es 'TOT'
indices_a_eliminar = df_filtered[df_filtered['Team'] == 'TOT'].index

# Eliminar las filas con los índices especificados
df2_cleaned = df_filtered.drop(index=indices_a_eliminar)

# Mostrar el DataFrame resultante
print("DataFrame después de eliminar filas donde 'Team' es 'TOT':")
print(df2_cleaned)
# Out:
# DataFrame después de eliminar filas donde 'Team' es 'TOT':
#                 Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1         Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2          Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3         Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4    LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 807     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  ...
# 808         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 809     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 810        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 811        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1  2022
# 1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9  2022
# 2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1  2022
# 3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1  2022
# 4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9  2022
# ..   ...  ...   ...  ...  ...  ...  ...  ...   ...   ...
# 807  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3  2022
# 808  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4  2022
# 809  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3  2022
# 810  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2  2022
# 811  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3  2022
#
# [715 rows x 30 columns]

# %%
# Filtrar filas donde 'Team' es 'TOT'
df_tot = df2_cleaned[df2_cleaned['Team'] == 'TOT']

# Mostrar el resultado
print(df2_cleaned)
# Out:
#                 Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1         Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2          Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3         Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4    LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 807     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  ...
# 808         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 809     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 810        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 811        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Temp
# 0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1  2022
# 1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9  2022
# 2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1  2022
# 3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1  2022
# 4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9  2022
# ..   ...  ...   ...  ...  ...  ...  ...  ...   ...   ...
# 807  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3  2022
# 808  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4  2022
# 809  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3  2022
# 810  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2  2022
# 811  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3  2022
#
# [715 rows x 30 columns]

# %% [markdown]
# Guardamos la temporada ya con su respectivo proceso ETL.

# %%
df2_cleaned.to_csv("Temporada2021_2022.csv",sep=",")

# %% [markdown]
# # ANALISIS TEMPORADA 2022 - 2023

# %%
df3 = pd.read_csv("nba_2022-23_all_stats_with_salary.csv") 
print(df3.head(11))
# Out:
#     Unnamed: 0            Player Name    Salary Position  Age     Team  GP  \
# 0            0          Stephen Curry  48070014       PG   34      GSW  56
# 1            1              John Wall  47345760       PG   32      LAC  34
# 2            2      Russell Westbrook  47080179       PG   34  LAL/LAC  73
# 3            3           LeBron James  44474988       PF   38      LAL  55
# 4            4           Kevin Durant  44119845       PF   34  BRK/PHO  47
# 5            5           Bradley Beal  43279250       SG   29      WAS  50
# 6            6          Kawhi Leonard  42492492       SF   31      LAC  52
# 7            7            Paul George  42492492       SF   32      LAC  56
# 8            8  Giannis Antetokounmpo  42492492       PF   28      MIL  63
# 9            9         Damian Lillard  42492492       PG   32      POR  58
# 10          10          Klay Thompson  40600080       SF   32      GSW  69
#
#     GS    MP    FG  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  \
# 0   56  34.7  10.0  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5
# 1    3  22.2   4.1  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2
# 2   24  29.1   5.9  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2
# 3   54  35.5  11.1  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1
# 4   47  35.6  10.3  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1
# 5   50  33.5   8.9  ...  12.9  29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8
# 6   50  33.6   8.6  ...   8.1  27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1
# 7   56  34.6   8.2  ...  13.4  29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8
# 8   63  32.1  11.2  ...  13.2  38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5
# 9   58  36.3   9.6  ...  11.7  33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1
# 10  69  33.0   7.9  ...   8.6  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3
#
#     VORP
# 0    4.7
# 1    0.1
# 2    1.2
# 3    4.0
# 4    3.9
# 5    1.6
# 6    3.5
# 7    2.3
# 8    5.4
# 9    4.9
# 10   1.0
#
# [11 rows x 52 columns]

# %%
df3.drop(df3.columns[0], axis=1, inplace=True)

# %%
print(df3.head(11))
# Out:
#               Player Name    Salary Position  Age     Team  GP  GS    MP  \
# 0           Stephen Curry  48070014       PG   34      GSW  56  56  34.7
# 1               John Wall  47345760       PG   32      LAC  34   3  22.2
# 2       Russell Westbrook  47080179       PG   34  LAL/LAC  73  24  29.1
# 3            LeBron James  44474988       PF   38      LAL  55  54  35.5
# 4            Kevin Durant  44119845       PF   34  BRK/PHO  47  47  35.6
# 5            Bradley Beal  43279250       SG   29      WAS  50  50  33.5
# 6           Kawhi Leonard  42492492       SF   31      LAC  52  50  33.6
# 7             Paul George  42492492       SF   32      LAC  56  56  34.6
# 8   Giannis Antetokounmpo  42492492       PF   28      MIL  63  63  32.1
# 9          Damian Lillard  42492492       PG   32      POR  58  58  36.3
# 10          Klay Thompson  40600080       SF   32      GSW  69  69  33.0
#
#       FG   FGA  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   10.0  20.2  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7
# 1    4.1   9.9  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1
# 2    5.9  13.6  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2
# 3   11.1  22.2  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0
# 4   10.3  18.3  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9
# 5    8.9  17.6  ...  12.9  29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8   1.6
# 6    8.6  16.8  ...   8.1  27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1   3.5
# 7    8.2  17.9  ...  13.4  29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8   2.3
# 8   11.2  20.3  ...  13.2  38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5   5.4
# 9    9.6  20.7  ...  11.7  33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1   4.9
# 10   7.9  18.1  ...   8.6  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3   1.0
#
# [11 rows x 51 columns]

# %%
print(df3.describe())
# Out:
#              Salary         Age          GP          GS          MP  \
# count  4.670000e+02  467.000000  467.000000  467.000000  467.000000
# mean   8.416599e+06   25.820128   48.233405   22.650964   19.871306
# std    1.070812e+07    4.275113   24.807740   27.094577    9.548684
# min    5.849000e+03   19.000000    1.000000    0.000000    1.800000
# 25%    1.782621e+06   23.000000   31.000000    1.000000   12.500000
# 50%    3.722040e+06   25.000000   55.000000    8.000000   19.200000
# 75%    1.063354e+07   29.000000   68.500000   45.500000   28.300000
# max    4.807001e+07   42.000000   83.000000   83.000000   41.000000
#
#                FG         FGA         FG%          3P         3PA  ...  \
# count  467.000000  467.000000  466.000000  467.000000  467.000000  ...
# mean     3.351392    7.117773    0.465009    0.996574    2.792719  ...
# std      2.457836    5.020700    0.109547    0.880468    2.260794  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      1.600000    3.300000    0.417000    0.300000    1.000000  ...
# 50%      2.700000    5.800000    0.455000    0.800000    2.400000  ...
# 75%      4.300000    9.400000    0.507500    1.500000    4.150000  ...
# max     11.200000   22.200000    1.000000    4.900000   11.400000  ...
#
#              TOV%        USG%         OWS         DWS          WS       WS/48  \
# count  467.000000  467.000000  467.000000  467.000000  467.000000  467.000000
# mean    12.735974   18.425910    1.208351    1.120557    2.328908    0.081771
# std      7.198533    5.909528    1.765160    0.980478    2.533094    0.088089
# min      0.000000    5.100000   -1.900000    0.000000   -1.600000   -0.517000
# 25%      9.500000   14.300000    0.000000    0.300000    0.300000    0.047000
# 50%     11.900000   17.600000    0.600000    0.900000    1.500000    0.087000
# 75%     15.000000   21.150000    1.800000    1.800000    3.550000    0.129500
# max    100.000000   52.500000    9.600000    4.800000   12.600000    0.626000
#
#              OBPM        DBPM         BPM        VORP
# count  467.000000  467.000000  467.000000  467.000000
# mean    -1.344968   -0.087152   -1.432548    0.539829
# std      3.578193    2.243437    4.925175    1.172960
# min    -22.500000  -10.400000  -26.500000   -1.300000
# 25%     -2.900000   -0.900000   -3.300000   -0.100000
# 50%     -1.300000   -0.100000   -1.300000    0.100000
# 75%      0.450000    0.800000    0.600000    0.800000
# max     17.000000   32.700000   48.600000    6.400000
#
# [8 rows x 48 columns]

# %% [markdown]
# Se eliminan las columnas que no sirven. En este caso contenian información no relevante.

# %%
df3.drop(df3.columns[30], axis=1, inplace=True)

# %%
df3.drop(df3.columns[1], axis=1, inplace=True)

# %%
df3.head(11)
# Out:
#               Player Name Position  Age     Team  GP  GS    MP    FG   FGA  \
# 0           Stephen Curry       PG   34      GSW  56  56  34.7  10.0  20.2
# 1               John Wall       PG   32      LAC  34   3  22.2   4.1   9.9
# 2       Russell Westbrook       PG   34  LAL/LAC  73  24  29.1   5.9  13.6
# 3            LeBron James       PF   38      LAL  55  54  35.5  11.1  22.2
# 4            Kevin Durant       PF   34  BRK/PHO  47  47  35.6  10.3  18.3
# 5            Bradley Beal       SG   29      WAS  50  50  33.5   8.9  17.6
# 6           Kawhi Leonard       SF   31      LAC  52  50  33.6   8.6  16.8
# 7             Paul George       SF   32      LAC  56  56  34.6   8.2  17.9
# 8   Giannis Antetokounmpo       PF   28      MIL  63  63  32.1  11.2  20.3
# 9          Damian Lillard       PG   32      POR  58  58  36.3   9.6  20.7
# 10          Klay Thompson       SF   32      GSW  69  69  33.0   7.9  18.1
#
#       FG%  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   0.493  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7
# 1   0.408  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1
# 2   0.436  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2
# 3   0.500  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0
# 4   0.560  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9
# 5   0.506  ...  12.9  29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8   1.6
# 6   0.512  ...   8.1  27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1   3.5
# 7   0.457  ...  13.4  29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8   2.3
# 8   0.553  ...  13.2  38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5   5.4
# 9   0.463  ...  11.7  33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1   4.9
# 10  0.436  ...   8.6  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3   1.0
#
# [11 rows x 49 columns]

# %% [markdown]
# Verificamos valores nulos

# %%
ValoresNull3 = df3.isnull().sum() [df3.isnull().sum()>0]
print(ValoresNull3)
# Out:
# FG%      1
# 3P%     13
# 2P%      4
# eFG%     1
# FT%     23
# TS%      1
# 3PAr     1
# FTr      1
# dtype: int64

# %%
# Filtrar filas que contienen al menos un valor nulo
filas_con_nulos = df3[df3.isnull().any(axis=1)]

# Mostrar las primeras filas con valores nulos

np.shape(filas_con_nulos)
# Out:
# (34, 49)

# %% [markdown]
# Observamos los valores nulos. Es la primer temporada en presentar valores nulos. A continuación en base a la naturaleza de los nulos fijaremos parámetros para tratarlos.

# %%
filas_con_nulos
# Out:
#            Player Name Position  Age     Team  GP  GS    MP   FG  FGA    FG%  \
# 75   Mitchell Robinson        C   24      NYK  59  58  27.0  3.2  4.7  0.671
# 133      Mason Plumlee        C   32  LAC/CHO  79  60  26.0  4.2  6.1  0.680
# 221      Dylan Windler       SF   26      CLE   3   0   3.3  0.7  1.0  0.667
# 233      Mark Williams        C   21      CHO  43  17  19.3  3.7  5.8  0.637
# 247     Sterling Brown       SF   27      LAL   4   0   6.0  0.0  1.0  0.000
# 254       Joe Wieskamp       SF   23      TOR   9   0   5.6  0.3  1.6  0.214
# 264    Bismack Biyombo        C   30      PHO  61  14  14.3  2.0  3.4  0.578
# 301     Udoka Azubuike        C   23      UTA  36   4  10.0  1.6  2.0  0.819
# 332     Daniel Gafford        C   24      WAS  78  47  20.6  3.7  5.1  0.732
# 344   Ryan Arcidiacono       PG   28  NYK/POR  20   4   8.6  0.5  1.9  0.243
# 356    Leandro Bolmaro       SF   22      UTA  14   0   4.9  0.2  1.4  0.150
# 358       Jared Butler       PG   22      OKC   6   1  12.8  2.5  5.3  0.469
# 393  Justin Champagnie       SF   21  BOS/TOR   5   0   6.8  1.0  3.0  0.333
# 395        Moses Brown        C   23  BRK/LAC  36   1   8.2  1.7  2.7  0.635
# 397          PJ Dozier       SF   26      SAC  16   0   4.9  0.6  2.1  0.303
# 403       Trevor Keels       SG   19      NYK   3   0   2.7  0.3  1.3  0.250
# 404     Dereon Seabron       SG   22      NOP   5   0   2.4  0.4  1.0  0.400
# 408       Malcolm Hill       SF   27      CHI   5   0   1.8  0.4  0.8  0.500
# 416        Cole Swider       SF   23      LAL   7   0   5.9  0.4  1.3  0.333
# 421      Neemias Queta        C   23      SAC   5   0   5.8  1.2  1.8  0.667
# 425       Micah Potter       PF   24      UTA   7   0   7.4  1.4  2.1  0.667
# 428       Chima Moneke       SF   27      SAC   2   0   4.0  0.5  1.0  0.500
# 436   Alondes Williams       SG   23      BRK   1   0   5.0  0.0  0.0    NaN
# 437   Donovan Williams       SG   21      ATL   2   0   2.0  1.0  2.5  0.400
# 439        Chris Silva       PF   26      DAL   1   0   3.0  1.0  1.0  1.000
# 440       Tyler Dorsey       SF   26      DAL   3   0   2.7  1.3  1.7  0.800
# 441        Braxton Key       SF   25      DET   3   0   3.0  0.3  0.3  1.000
# 444       Devon Dotson       PG   23      WAS   6   0   8.8  0.2  1.7  0.100
# 449        Xavier Moon       SG   28      LAC   4   0   5.0  0.8  2.3  0.333
# 453      Frank Jackson       PG   24      UTA   1   0   5.0  0.0  3.0  0.000
# 454      Deonte Burton       PF   29      SAC   2   0   3.0  0.0  1.0  0.000
# 458     Jordan Schakel       SF   24      WAS   2   0   3.0  0.5  1.0  0.500
# 459      Stanley Umude       SG   23      DET   1   0   2.0  0.0  1.0  0.000
# 466      Jacob Gilyard       PG   24      MEM   1   0  41.0  1.0  3.0  0.333
#
#      ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 75   ...   10.9  10.1  4.0  2.6  6.5  0.197   1.0   1.4   2.4   1.7
# 133  ...   15.8  15.2  5.5  2.4  7.9  0.185   1.2   1.0   2.2   2.2
# 221  ...   25.0  17.9  0.0  0.0  0.0  0.149   3.2   3.5   6.7   0.0
# 233  ...   12.0  17.0  1.5  1.3  2.8  0.163  -0.5   0.6   0.1   0.4
# 247  ...    0.0   7.0  0.0  0.1  0.0  0.040  -7.7   4.3  -3.3   0.0
# 254  ...    6.7  12.8 -0.1  0.0 -0.1 -0.076  -7.0  -3.6 -10.6  -0.1
# 264  ...   17.7  14.0  0.2  1.6  1.9  0.102  -3.4   2.5  -0.9   0.2
# 301  ...   18.2  11.5  0.6  0.4  1.0  0.134  -1.2   0.5  -0.6   0.1
# 332  ...   15.1  15.2  4.2  1.9  6.1  0.184   0.4   0.6   1.0   1.2
# 344  ...   15.9  11.1 -0.2  0.1 -0.2 -0.043  -7.3  -1.5  -8.8  -0.3
# 356  ...   25.9  16.6 -0.4  0.0 -0.3 -0.231 -12.4  -2.3 -14.7  -0.2
# 358  ...   13.5  20.1  0.0  0.1  0.1  0.061  -2.2  -0.4  -2.6   0.0
# 393  ...    0.0  19.2  0.0  0.0  0.0  0.009  -5.1  -2.8  -7.9  -0.1
# 395  ...   10.5  21.2  0.7  0.4  1.1  0.179   0.6  -1.2  -0.6   0.1
# 397  ...   13.2  20.6 -0.3  0.1 -0.2 -0.097  -8.6   0.7  -7.8  -0.1
# 403  ...    0.0  21.4  0.0  0.0  0.0 -0.062  -7.4  -5.6 -13.0   0.0
# 404  ...    0.0  17.9  0.0  0.0  0.0 -0.034  -6.6  -4.7 -11.3   0.0
# 408  ...    0.0  19.7  0.0  0.0  0.0  0.125   1.6   0.8   2.4   0.0
# 416  ...    0.0   9.3  0.0  0.0  0.1  0.080  -2.9  -0.5  -3.4   0.0
# 421  ...    9.2  16.1  0.1  0.0  0.1  0.149  -2.6  -0.8  -3.4   0.0
# 425  ...   11.8  13.7  0.2  0.0  0.2  0.186   2.4   1.2   3.5   0.1
# 428  ...   41.0  26.2  0.0  0.0  0.0 -0.288 -12.7  -8.0 -20.7   0.0
# 436  ...  100.0  17.7 -0.1  0.0 -0.1 -0.517 -21.3  -5.2 -26.5   0.0
# 437  ...    0.0  52.5  0.0  0.0  0.0 -0.225  -9.1  -6.1 -15.2   0.0
# 439  ...   50.0  30.1  0.0  0.0  0.0 -0.260 -22.5  -0.1 -22.6   0.0
# 440  ...    0.0  28.3  0.1  0.0  0.1  0.367  17.0   0.8  17.8   0.0
# 441  ...    0.0   8.9  0.0  0.0  0.0  0.242   2.1   0.8   2.9   0.0
# 444  ...   23.1  10.7 -0.1  0.1  0.0 -0.025  -7.0   1.8  -5.3   0.0
# 449  ...   10.0  21.8  0.0  0.0  0.0 -0.030  -4.1  -1.0  -5.1   0.0
# 453  ...    0.0  25.1  0.0  0.0  0.0 -0.378 -12.5  -9.8 -22.2   0.0
# 454  ...    0.0  14.3  0.0  0.0  0.0 -0.347 -13.9 -10.4 -24.2   0.0
# 458  ...    0.0  14.5  0.0  0.0  0.0  0.314   7.7   9.3  17.0   0.0
# 459  ...    0.0  40.0  0.0  0.0  0.0  0.626  15.9  32.7  48.6   0.0
# 466  ...   40.0   5.1  0.0  0.1  0.1  0.079  -7.8   1.7  -6.1   0.0
#
# [34 rows x 49 columns]

# %% [markdown]
# Consultaremos los datos oficiales de la página de la nba (www.nba.com)

# %% [markdown]
# Esto lo haremos columna por columna debido a la delicada naturaleza de cada estadistica.

# %%
columnas_a_imprimir = ['Player Name','FG%']
print(filas_con_nulos[columnas_a_imprimir])
# Out:
#            Player Name    FG%
# 75   Mitchell Robinson  0.671
# 133      Mason Plumlee  0.680
# 221      Dylan Windler  0.667
# 233      Mark Williams  0.637
# 247     Sterling Brown  0.000
# 254       Joe Wieskamp  0.214
# 264    Bismack Biyombo  0.578
# 301     Udoka Azubuike  0.819
# 332     Daniel Gafford  0.732
# 344   Ryan Arcidiacono  0.243
# 356    Leandro Bolmaro  0.150
# 358       Jared Butler  0.469
# 393  Justin Champagnie  0.333
# 395        Moses Brown  0.635
# 397          PJ Dozier  0.303
# 403       Trevor Keels  0.250
# 404     Dereon Seabron  0.400
# 408       Malcolm Hill  0.500
# 416        Cole Swider  0.333
# 421      Neemias Queta  0.667
# 425       Micah Potter  0.667
# 428       Chima Moneke  0.500
# 436   Alondes Williams    NaN
# 437   Donovan Williams  0.400
# 439        Chris Silva  1.000
# 440       Tyler Dorsey  0.800
# 441        Braxton Key  1.000
# 444       Devon Dotson  0.100
# 449        Xavier Moon  0.333
# 453      Frank Jackson  0.000
# 454      Deonte Burton  0.000
# 458     Jordan Schakel  0.500
# 459      Stanley Umude  0.000
# 466      Jacob Gilyard  0.333

# %% [markdown]
#  Alondes Williams el unico valor faltante de aquí no tiene su estadística disponible en la página de la NBA entonces para no generar data errónea lo mejor será colocarle 0.

# %%
# Rellenar valores faltantes de Alondes Williams con 0 en la fila con índice 436
alondes = [436]
df3.loc[alondes, 'FG%'] = df3.loc[alondes, 'FG%'].fillna(0)

# %%
columnas_a_imprimir = ['Player Name','3P%']
print(filas_con_nulos[columnas_a_imprimir])
# Out:
#            Player Name    3P%
# 75   Mitchell Robinson    NaN
# 133      Mason Plumlee    NaN
# 221      Dylan Windler  0.500
# 233      Mark Williams    NaN
# 247     Sterling Brown  0.000
# 254       Joe Wieskamp  0.250
# 264    Bismack Biyombo    NaN
# 301     Udoka Azubuike    NaN
# 332     Daniel Gafford    NaN
# 344   Ryan Arcidiacono  0.348
# 356    Leandro Bolmaro  0.000
# 358       Jared Butler  0.500
# 393  Justin Champagnie  0.200
# 395        Moses Brown    NaN
# 397          PJ Dozier  0.125
# 403       Trevor Keels  0.250
# 404     Dereon Seabron    NaN
# 408       Malcolm Hill  0.333
# 416        Cole Swider  0.375
# 421      Neemias Queta    NaN
# 425       Micah Potter  0.571
# 428       Chima Moneke    NaN
# 436   Alondes Williams    NaN
# 437   Donovan Williams  0.000
# 439        Chris Silva    NaN
# 440       Tyler Dorsey  0.500
# 441        Braxton Key    NaN
# 444       Devon Dotson  0.250
# 449        Xavier Moon  0.333
# 453      Frank Jackson  0.000
# 454      Deonte Burton  0.000
# 458     Jordan Schakel  1.000
# 459      Stanley Umude  0.000
# 466      Jacob Gilyard  0.333

# %% [markdown]
# En el caso de estos valores faltantes, si figuran en la página oficial de NBA pero aparecen como 0%.
#
# Esto refleja que hay jugadores que no tuvieron oportunidades de hacer tiros de 3 puntos.
#
#  Procedo a rellenarlos con 0.

# %%
indices = [75,133,233,264,301,332,395,404,421,428,436,441,439]
df3.loc[indices, '3P%'] = df3.loc[indices, '3P%'].fillna(0)

# %%
columnas_a_imprimir = ['Player Name','2P%']
print(filas_con_nulos[columnas_a_imprimir])
# Out:
#            Player Name    2P%
# 75   Mitchell Robinson  0.671
# 133      Mason Plumlee  0.680
# 221      Dylan Windler  1.000
# 233      Mark Williams  0.637
# 247     Sterling Brown  0.000
# 254       Joe Wieskamp  0.000
# 264    Bismack Biyombo  0.578
# 301     Udoka Azubuike  0.819
# 332     Daniel Gafford  0.732
# 344   Ryan Arcidiacono  0.071
# 356    Leandro Bolmaro  0.188
# 358       Jared Butler  0.444
# 393  Justin Champagnie  0.400
# 395        Moses Brown  0.635
# 397          PJ Dozier  0.471
# 403       Trevor Keels    NaN
# 404     Dereon Seabron  0.400
# 408       Malcolm Hill  1.000
# 416        Cole Swider  0.000
# 421      Neemias Queta  0.667
# 425       Micah Potter  0.750
# 428       Chima Moneke  0.500
# 436   Alondes Williams    NaN
# 437   Donovan Williams  0.667
# 439        Chris Silva  1.000
# 440       Tyler Dorsey  1.000
# 441        Braxton Key  1.000
# 444       Devon Dotson  0.000
# 449        Xavier Moon  0.333
# 453      Frank Jackson  0.000
# 454      Deonte Burton  0.000
# 458     Jordan Schakel  0.000
# 459      Stanley Umude    NaN
# 466      Jacob Gilyard    NaN

# %% [markdown]
# Stanley Umude: No tuvo estadísticas de la NBA para la temporada 2022-2023, ya que no jugó en partidos de temporada regular.
#
# Jacob Gilyard: Similar a Umude, Jacob Gilyard no jugó en la NBA durante la temporada 2022-2023, por lo que no tiene estadísticas de 2P%.
#
# Trevor Keels: Trevor Keels, quien también fue novato en la temporada 2022-2023, jugó para los New York Knicks y tuvo un porcentaje de tiros de campo de dos puntos (2P%) de 33.3% en los partidos que disputó.
#
# Alondes Williams: Alondes Williams tampoco tuvo estadísticas en la NBA durante la temporada 2022-2023, ya que no participó en partidos de temporada regular.

# %%
indices = [466,459,436]
df3.loc[indices, '2P%'] = df3.loc[indices, '2P%'].fillna(0)
trevor_keels = [403]
df3.loc[trevor_keels, '2P%'] = df3.loc[trevor_keels, '2P%'].fillna(0.333)

# %%
columnas_a_imprimir = ['Player Name','eFG%']
print(filas_con_nulos[columnas_a_imprimir])
# Out:
#            Player Name   eFG%
# 75   Mitchell Robinson  0.671
# 133      Mason Plumlee  0.680
# 221      Dylan Windler  0.833
# 233      Mark Williams  0.637
# 247     Sterling Brown  0.000
# 254       Joe Wieskamp  0.321
# 264    Bismack Biyombo  0.578
# 301     Udoka Azubuike  0.819
# 332     Daniel Gafford  0.732
# 344   Ryan Arcidiacono  0.351
# 356    Leandro Bolmaro  0.150
# 358       Jared Butler  0.578
# 393  Justin Champagnie  0.367
# 395        Moses Brown  0.635
# 397          PJ Dozier  0.333
# 403       Trevor Keels  0.375
# 404     Dereon Seabron  0.400
# 408       Malcolm Hill  0.625
# 416        Cole Swider  0.500
# 421      Neemias Queta  0.667
# 425       Micah Potter  0.800
# 428       Chima Moneke  0.500
# 436   Alondes Williams    NaN
# 437   Donovan Williams  0.400
# 439        Chris Silva  1.000
# 440       Tyler Dorsey  0.900
# 441        Braxton Key  1.000
# 444       Devon Dotson  0.150
# 449        Xavier Moon  0.389
# 453      Frank Jackson  0.000
# 454      Deonte Burton  0.000
# 458     Jordan Schakel  0.750
# 459      Stanley Umude  0.000
# 466      Jacob Gilyard  0.500

# %%
alondes = [436]
df3.loc[alondes, 'eFG%'] = df3.loc[alondes, 'eFG%'].fillna(0)

# %%
columnas_a_imprimir = ['Player Name','FT%']
print(filas_con_nulos[columnas_a_imprimir])
# Out:
#            Player Name    FT%
# 75   Mitchell Robinson  0.484
# 133      Mason Plumlee  0.636
# 221      Dylan Windler    NaN
# 233      Mark Williams  0.691
# 247     Sterling Brown    NaN
# 254       Joe Wieskamp    NaN
# 264    Bismack Biyombo  0.357
# 301     Udoka Azubuike  0.350
# 332     Daniel Gafford  0.679
# 344   Ryan Arcidiacono    NaN
# 356    Leandro Bolmaro    NaN
# 358       Jared Butler    NaN
# 393  Justin Champagnie    NaN
# 395        Moses Brown  0.458
# 397          PJ Dozier    NaN
# 403       Trevor Keels    NaN
# 404     Dereon Seabron    NaN
# 408       Malcolm Hill    NaN
# 416        Cole Swider    NaN
# 421      Neemias Queta  0.000
# 425       Micah Potter    NaN
# 428       Chima Moneke  0.000
# 436   Alondes Williams    NaN
# 437   Donovan Williams    NaN
# 439        Chris Silva    NaN
# 440       Tyler Dorsey    NaN
# 441        Braxton Key  1.000
# 444       Devon Dotson    NaN
# 449        Xavier Moon    NaN
# 453      Frank Jackson    NaN
# 454      Deonte Burton    NaN
# 458     Jordan Schakel    NaN
# 459      Stanley Umude  1.000
# 466      Jacob Gilyard    NaN

# %% [markdown]
# Estas fueron las stats oficiales (FT%) de la pagina NBA para cada jugador.
#
# Dylan Windler: 70.4%
#
# Sterling Brown: 78.6%
#
# Joe Wieskamp: 71.4%
#
# Ryan Arcidiacono: 80.0%
#
# Leandro Bolmaro: 68.8%
#
# Jared Butler: 76.2%
#
# Justin Champagnie: 76.5%
#
# P.J. Dozier: 69.4%
#
# Trevor Keels: 63.6%
#
# Dereon Seabron: 77.8%
#
# Malcolm Hill: 81.8%
#
# Cole Swider: — (No jugó en la NBA durante la temporada 2022-2023)
#
# Micah Potter: — (No jugó en la NBA durante la temporada 2022-2023)
#
# Alondes Williams: — (No jugó en la NBA durante la temporada 2022-2023)
#
# Donovan Williams: — (No jugó en la NBA durante la temporada 2022-2023)
#
# Chris Silva: 78.9%
#
# Tyler Dorsey: 83.3%
#
# Devon Dotson: 80.0%
#
# Xavier Moon: 82.8%
#
# Frank Jackson: 83.0%
#
# Deonte Burton: 80.0%
#
# Jordan Schakel: — (No jugó en la NBA durante la temporada 2022-2023)
#
# Jacob Gilyard: — (No jugó en la NBA durante la temporada 2022-2023)

# %%
# Diccionario con valores de reemplazo
reemplazos = {
    'Dylan Windler': 0.704,
    'Sterling Brown': 0.786,
    'Joe Wieskamp': 0.714,
    'Ryan Arcidiacono': 0.800,
    'Leandro Bolmaro': 0.688,
    'Jared Butler': 0.762,
    'Justin Champagnie': 0.765,
    'PJ Dozier': 0.694,
    'Trevor Keels': 0.636,
    'Dereon Seabron': 0.778,
    'Malcolm Hill': 0.818,
    'Cole Swider': 0,  # No jugó
    'Micah Potter': 0,  # No jugó
    'Alondes Williams': 0,  # No jugó
    'Donovan Williams': 0,  # No jugó
    'Chris Silva': 0.789,
    'Tyler Dorsey': 0.833,
    'Devon Dotson': 0.800,
    'Xavier Moon': 0.828,
    'Frank Jackson': 0.830,
    'Deonte Burton': 0.800,
    'Jordan Schakel': 0,  # No jugó
    'Jacob Gilyard': 0  # No jugó
}

# Rellenar los valores faltantes en la columna 'FT%' con el diccionario de reemplazo
df3['FT%'] = df3.apply(lambda row: reemplazos.get(row['Player Name'], row['FT%']), axis=1)

# %% [markdown]
# Checkeo nuevamente valores faltantes:

# %%
ValoresNull3 = df3.isnull().sum() [df3.isnull().sum()>0]
print(ValoresNull3)
# Out:
# TS%     1
# 3PAr    1
# FTr     1
# dtype: int64

# %%
# Lista de columnas para las que se reemplazarán los valores nulos con la media
columnas_objetivo = ['FG%', '3P%', '2P%', 'eFG%', 'FT%']

# Reemplazar los valores nulos de las columnas especificadas por su media
for columna in columnas_objetivo:
    media_columna = df3[columna].mean()
    df3[columna] = df3[columna].fillna(media_columna)

# Mostrar las primeras filas del DataFrame para verificar
print(df3.head(11))
# Out:
#               Player Name Position  Age     Team  GP  GS    MP    FG   FGA  \
# 0           Stephen Curry       PG   34      GSW  56  56  34.7  10.0  20.2
# 1               John Wall       PG   32      LAC  34   3  22.2   4.1   9.9
# 2       Russell Westbrook       PG   34  LAL/LAC  73  24  29.1   5.9  13.6
# 3            LeBron James       PF   38      LAL  55  54  35.5  11.1  22.2
# 4            Kevin Durant       PF   34  BRK/PHO  47  47  35.6  10.3  18.3
# 5            Bradley Beal       SG   29      WAS  50  50  33.5   8.9  17.6
# 6           Kawhi Leonard       SF   31      LAC  52  50  33.6   8.6  16.8
# 7             Paul George       SF   32      LAC  56  56  34.6   8.2  17.9
# 8   Giannis Antetokounmpo       PF   28      MIL  63  63  32.1  11.2  20.3
# 9          Damian Lillard       PG   32      POR  58  58  36.3   9.6  20.7
# 10          Klay Thompson       SF   32      GSW  69  69  33.0   7.9  18.1
#
#       FG%  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   0.493  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7
# 1   0.408  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1
# 2   0.436  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2
# 3   0.500  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0
# 4   0.560  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9
# 5   0.506  ...  12.9  29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8   1.6
# 6   0.512  ...   8.1  27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1   3.5
# 7   0.457  ...  13.4  29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8   2.3
# 8   0.553  ...  13.2  38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5   5.4
# 9   0.463  ...  11.7  33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1   4.9
# 10  0.436  ...   8.6  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3   1.0
#
# [11 rows x 49 columns]

# %%
# Mostrar el valor de la columna 'FT%' en la fila 221
valor_fila_221 = df3.loc[221, 'FT%']
print(f"Valor en la fila 221 de 'FT%': {valor_fila_221}")

# Mostrar el valor de la columna 'FT%' en la fila 247
valor_fila_247 = df3.loc[247, 'FT%']
print(f"Valor en la fila 247 de 'FT%': {valor_fila_247}")
# Out:
# Valor en la fila 221 de 'FT%': 0.704
# Valor en la fila 247 de 'FT%': 0.786

# %%
nuevos_nombres = {
    'Player Name': 'Player',
    'Position': 'Pos'
}

# Renombrar las columnas especificadas
df3.rename(columns=nuevos_nombres, inplace=True)


# Mostrar las primeras filas del DataFrame para verificar los cambios
print(df3.head())
# Out:
#               Player Pos  Age     Team  GP  GS    MP    FG   FGA    FG%  ...  \
# 0      Stephen Curry  PG   34      GSW  56  56  34.7  10.0  20.2  0.493  ...
# 1          John Wall  PG   32      LAC  34   3  22.2   4.1   9.9  0.408  ...
# 2  Russell Westbrook  PG   34  LAL/LAC  73  24  29.1   5.9  13.6  0.436  ...
# 3       LeBron James  PF   38      LAL  55  54  35.5  11.1  22.2  0.500  ...
# 4       Kevin Durant  PF   34  BRK/PHO  47  47  35.6  10.3  18.3  0.560  ...
#
#    TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7
# 1  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1
# 2  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2
# 3  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0
# 4  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9
#
# [5 rows x 49 columns]

# %%
# Año que deseas agregar
Temporada3 = 2023

# Agregar una nueva columna 'Team' con el valor del año especificado
df3['Temp'] = Temporada3

# Mostrar las primeras filas del DataFrame para verificar
print(df3.head())
# Out:
#               Player Pos  Age     Team  GP  GS    MP    FG   FGA    FG%  ...  \
# 0      Stephen Curry  PG   34      GSW  56  56  34.7  10.0  20.2  0.493  ...
# 1          John Wall  PG   32      LAC  34   3  22.2   4.1   9.9  0.408  ...
# 2  Russell Westbrook  PG   34  LAL/LAC  73  24  29.1   5.9  13.6  0.436  ...
# 3       LeBron James  PF   38      LAL  55  54  35.5  11.1  22.2  0.500  ...
# 4       Kevin Durant  PF   34  BRK/PHO  47  47  35.6  10.3  18.3  0.560  ...
#
#    USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  Temp
# 0  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7  2023
# 1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1  2023
# 2  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2  2023
# 3  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0  2023
# 4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9  2023
#
# [5 rows x 50 columns]

# %%
np.shape(df3)
# Out:
# (467, 50)

# %%
df3.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'Temp'],
#       dtype='object')

# %%
# Obtener los valores únicos de la columna team_abbreviation
valores_unicos = df3['Team'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['GSW' 'LAC' 'LAL/LAC' 'LAL' 'BRK/PHO' 'WAS' 'MIL' 'POR' 'BRK/DAL' 'MIN'
#  'MIA' 'PHI' 'DAL' 'ATL' 'CHI' 'BRK' 'TOR' 'IND' 'PHO' 'NOP' 'DEN'
#  'LAL/MIN' 'CLE' 'OKC' 'CLE/MIA' 'BOS' 'SAC' 'CHO' 'NYK' 'MIN/UTA'
#  'HOU/LAC' 'MEM' 'ORL' 'UTA' 'LAL/UTA' 'WAS/TOR' 'LAL/CHI' 'SAS' 'LAC/MEM'
#  'NYK/POR' 'NOP/SAS' 'CLE/MEM' 'ORL/PHO' 'DEN/LAC' 'DET' 'LAL/ORL'
#  'GSW/DET' 'HOU' 'SAS/TOR' 'BRK/DET' 'LAC/CHO' 'GSW/POR' 'PHI/MIA'
#  'LAL/WAS' 'DAL/ATL' 'ORL/IND' 'PHI/POR' 'OKC/PHO' 'MIL/IND' 'BOS/OKC'
#  'DET/POR' 'DET/ATL' 'HOU/ATL' 'PHI/PHO' 'DEN/LAL' 'PHI/CHO' 'CHI/IND'
#  'BRK/SAC' 'SAS/MIL' 'DET/OKC' 'BOS/TOR' 'BRK/LAC' 'SAS/PHI' 'BRK/MIA'
#  'MIA/WAS']

# %%
# Función para obtener el segundo equipo si hay más de uno
def get_second_team(team):
    teams = team.split('/')
    if len(teams) > 1:
        return teams[1]  # Retorna el segundo equipo
    return team  # Retorna el mismo equipo si solo hay uno

# Aplicar la función a la columna 'Team'
df3['Team'] = df3['Team'].apply(get_second_team)

print(df3)
# Out:
#                 Player Pos  Age Team  GP  GS    MP    FG   FGA    FG%  ...  \
# 0        Stephen Curry  PG   34  GSW  56  56  34.7  10.0  20.2  0.493  ...
# 1            John Wall  PG   32  LAC  34   3  22.2   4.1   9.9  0.408  ...
# 2    Russell Westbrook  PG   34  LAC  73  24  29.1   5.9  13.6  0.436  ...
# 3         LeBron James  PF   38  LAL  55  54  35.5  11.1  22.2  0.500  ...
# 4         Kevin Durant  PF   34  PHO  47  47  35.6  10.3  18.3  0.560  ...
# ..                 ...  ..  ...  ...  ..  ..   ...   ...   ...    ...  ...
# 462      Justin Minaya  SF   23  POR   4   0  22.3   1.8   5.8  0.304  ...
# 463       Kobi Simmons  SG   25  CHO   5   0   5.6   0.2   1.2  0.167  ...
# 464          Gabe York  SG   29  IND   3   0  18.7   2.7   7.0  0.381  ...
# 465       RaiQuan Gray  PF   23  BRK   1   0  35.0   6.0  12.0  0.500  ...
# 466      Jacob Gilyard  PG   24  MEM   1   0  41.0   1.0   3.0  0.333  ...
#
#      USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  Temp
# 0    31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7  2023
# 1    27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1  2023
# 2    27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2  2023
# 3    33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0  2023
# 4    30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9  2023
# ..    ...  ...  ...  ...    ...   ...   ...  ...   ...   ...
# 462  13.4 -0.2  0.1 -0.1 -0.067  -7.2  -1.9 -9.0  -0.2  2023
# 463  11.8  0.0  0.0  0.0  0.019  -1.0   0.1 -0.9   0.0  2023
# 464  16.4  0.1  0.0  0.1  0.091  -1.7  -1.8 -3.5   0.0  2023
# 465  21.4  0.0  0.0  0.1  0.106  -0.6  -1.4 -2.0   0.0  2023
# 466   5.1  0.0  0.1  0.1  0.079  -7.8   1.7 -6.1   0.0  2023
#
# [467 rows x 50 columns]

# %%
# Obtener los valores únicos de la columna team_abbreviation
valores_unicos = df3['Team'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['GSW' 'LAC' 'LAL' 'PHO' 'WAS' 'MIL' 'POR' 'DAL' 'MIN' 'MIA' 'PHI' 'ATL'
#  'CHI' 'BRK' 'TOR' 'IND' 'NOP' 'DEN' 'CLE' 'OKC' 'BOS' 'SAC' 'CHO' 'NYK'
#  'UTA' 'MEM' 'ORL' 'SAS' 'DET' 'HOU']

# %% [markdown]
# Guardamos el proceso etl de la temporada 2022-2023.

# %%
df3.to_csv("Temporada2022_2023.csv",sep=",")

# %% [markdown]
# ### ANALISIS SALARIOS 22-23

# %%
df4 = pd.read_csv("nba_2022-23_all_stats_with_salary.csv") 
print(df4.head(11))
# Out:
#     Unnamed: 0            Player Name    Salary Position  Age     Team  GP  \
# 0            0          Stephen Curry  48070014       PG   34      GSW  56
# 1            1              John Wall  47345760       PG   32      LAC  34
# 2            2      Russell Westbrook  47080179       PG   34  LAL/LAC  73
# 3            3           LeBron James  44474988       PF   38      LAL  55
# 4            4           Kevin Durant  44119845       PF   34  BRK/PHO  47
# 5            5           Bradley Beal  43279250       SG   29      WAS  50
# 6            6          Kawhi Leonard  42492492       SF   31      LAC  52
# 7            7            Paul George  42492492       SF   32      LAC  56
# 8            8  Giannis Antetokounmpo  42492492       PF   28      MIL  63
# 9            9         Damian Lillard  42492492       PG   32      POR  58
# 10          10          Klay Thompson  40600080       SF   32      GSW  69
#
#     GS    MP    FG  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  \
# 0   56  34.7  10.0  ...  12.5  31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5
# 1    3  22.2   4.1  ...  17.1  27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2
# 2   24  29.1   5.9  ...  18.4  27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2
# 3   54  35.5  11.1  ...  11.6  33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1
# 4   47  35.6  10.3  ...  13.4  30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1
# 5   50  33.5   8.9  ...  12.9  29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8
# 6   50  33.6   8.6  ...   8.1  27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1
# 7   56  34.6   8.2  ...  13.4  29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8
# 8   63  32.1  11.2  ...  13.2  38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5
# 9   58  36.3   9.6  ...  11.7  33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1
# 10  69  33.0   7.9  ...   8.6  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3
#
#     VORP
# 0    4.7
# 1    0.1
# 2    1.2
# 3    4.0
# 4    3.9
# 5    1.6
# 6    3.5
# 7    2.3
# 8    5.4
# 9    4.9
# 10   1.0
#
# [11 rows x 52 columns]

# %%
df4.drop(df4.columns[3:51], axis=1, inplace=True)

# %%
df4.drop(df4.columns[0], axis=1, inplace=True)

# %%
df4.drop(df4.columns[2], axis=1, inplace=True)

# %% [markdown]
# Lo que hicimos fue quedarnos con las columnas de Salario y nombre de jugador unicamente.

# %%
print(df4.head(11))
# Out:
#               Player Name    Salary
# 0           Stephen Curry  48070014
# 1               John Wall  47345760
# 2       Russell Westbrook  47080179
# 3            LeBron James  44474988
# 4            Kevin Durant  44119845
# 5            Bradley Beal  43279250
# 6           Kawhi Leonard  42492492
# 7             Paul George  42492492
# 8   Giannis Antetokounmpo  42492492
# 9          Damian Lillard  42492492
# 10          Klay Thompson  40600080

# %%
ValoresNull4 = df4.isnull().sum() [df4.isnull().sum()>0]
print(ValoresNull4)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Se revisaron valores nulos.

# %%
df4.isnull().sum()
# Out:
# Player Name    0
# Salary         0
# dtype: int64

# %%
df4.rename(columns={'Player Name': 'Player'}, inplace=True)

# %%
# Año que deseas agregar
Temporada4 = 2023

# Agregar una nueva columna 'Año' con el valor del año especificado
df4['Temp'] = Temporada4

# Mostrar las primeras filas del DataFrame para verificar
print(df4.head())
# Out:
#               Player    Salary  Temp
# 0      Stephen Curry  48070014  2023
# 1          John Wall  47345760  2023
# 2  Russell Westbrook  47080179  2023
# 3       LeBron James  44474988  2023
# 4       Kevin Durant  44119845  2023

# %% [markdown]
# Se guarda el dataset de salarios ya terminado.

# %%
df4.to_csv("Salarios.csv",sep=",")

# %% [markdown]
# # Se comienza a preparar todo para realizar el merge de temporadas.

# %%
df2021_2022 = pd.read_csv("Temporada2021_2022.csv") 
print(df3.head(11))
# Out:
#                    Player Pos  Age Team  GP  GS    MP    FG   FGA    FG%  ...  \
# 0           Stephen Curry  PG   34  GSW  56  56  34.7  10.0  20.2  0.493  ...
# 1               John Wall  PG   32  LAC  34   3  22.2   4.1   9.9  0.408  ...
# 2       Russell Westbrook  PG   34  LAC  73  24  29.1   5.9  13.6  0.436  ...
# 3            LeBron James  PF   38  LAL  55  54  35.5  11.1  22.2  0.500  ...
# 4            Kevin Durant  PF   34  PHO  47  47  35.6  10.3  18.3  0.560  ...
# 5            Bradley Beal  SG   29  WAS  50  50  33.5   8.9  17.6  0.506  ...
# 6           Kawhi Leonard  SF   31  LAC  52  50  33.6   8.6  16.8  0.512  ...
# 7             Paul George  SF   32  LAC  56  56  34.6   8.2  17.9  0.457  ...
# 8   Giannis Antetokounmpo  PF   28  MIL  63  63  32.1  11.2  20.3  0.553  ...
# 9          Damian Lillard  PG   32  POR  58  58  36.3   9.6  20.7  0.463  ...
# 10          Klay Thompson  SF   32  GSW  69  69  33.0   7.9  18.1  0.436  ...
#
#     USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  Temp
# 0   31.0  5.8  2.0  7.8  0.192   7.5   0.1  7.5   4.7  2023
# 1   27.0 -0.4  0.7  0.3  0.020  -0.8  -0.4 -1.2   0.1  2023
# 2   27.7 -0.6  2.6  1.9  0.044   0.3  -0.1  0.2   1.2  2023
# 3   33.3  3.2  2.4  5.6  0.138   5.5   0.6  6.1   4.0  2023
# 4   30.7  4.7  2.1  6.8  0.194   6.0   1.2  7.1   3.9  2023
# 5   29.2  2.2  1.2  3.4  0.099   2.9  -1.2  1.8   1.6  2023
# 6   27.0  4.9  2.2  7.1  0.194   5.1   0.9  6.1   3.5  2023
# 7   29.5  2.3  2.3  4.6  0.114   2.4   0.3  2.8   2.3  2023
# 8   38.8  4.9  3.7  8.6  0.204   5.8   2.7  8.5   5.4  2023
# 9   33.8  8.2  0.8  9.0  0.205   8.3  -1.2  7.1   4.9  2023
# 10  26.4  1.2  1.9  3.1  0.066   1.5  -1.7 -0.3   1.0  2023
#
# [11 rows x 50 columns]

# %%
# Cargar los tres archivos CSV en DataFrames
df1final = pd.read_csv('Temporada2020_2021.csv')
df2final = pd.read_csv('Temporada2021_2022.csv')
df3final = pd.read_csv('Temporada2022_2023.csv')

# Concatenar los DataFrames
df_combined = pd.concat([df1final, df2final, df3final], ignore_index=True)
df_combined = df_combined.drop('Unnamed: 0', axis=1)
# Guardar el DataFrame combinado en un nuevo archivo CSV
df_combined.to_csv('TempFinal.csv', index=False)

# %%
np.shape(df_combined)
# Out:
# (1671, 50)

# %% [markdown]
# Se realizó el merge y se procede a guardarlo en un .csv

# %%
df_combined
# Out:
#                  Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0      Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...
# 1          Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...
# 2          Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...
# 3           Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...
# 4     LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...
# ...                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 1666      Justin Minaya  SF   23  POR   4   0  22.3  1.8   5.8  0.304  ...
# 1667       Kobi Simmons  SG   25  CHO   5   0   5.6  0.2   1.2  0.167  ...
# 1668          Gabe York  SG   29  IND   3   0  18.7  2.7   7.0  0.381  ...
# 1669       RaiQuan Gray  PF   23  BRK   1   0  35.0  6.0  12.0  0.500  ...
# 1670      Jacob Gilyard  PG   24  MEM   1   0  41.0  1.0   3.0  0.333  ...
#
#       TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 1      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 2      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 3      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 4      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# ...    ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 1666  14.6  13.4 -0.2  0.1 -0.1 -0.067  -7.2  -1.9 -9.0  -0.2
# 1667  12.7  11.8  0.0  0.0  0.0  0.019  -1.0   0.1 -0.9   0.0
# 1668   0.0  16.4  0.1  0.0  0.1  0.091  -1.7  -1.8 -3.5   0.0
# 1669  23.7  21.4  0.0  0.0  0.1  0.106  -0.6  -1.4 -2.0   0.0
# 1670  40.0   5.1  0.0  0.1  0.1  0.079  -7.8   1.7 -6.1   0.0
#
# [1671 rows x 50 columns]

# %%
df_combined.head(11)
# Out:
#                       Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  \
# 0           Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590
# 1               Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125
# 2               Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603
# 3                Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573
# 4          LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476
# 5          Ty-Shon Alexander  SG   22  PHO   3   0   2.7  0.0   1.0  0.000
# 6   Nickeil Alexander-Walker  SG   22  NOP  23   3  19.2  3.3   8.2  0.410
# 7              Grayson Allen  SG   25  MEM  19   8  23.9  3.2   7.4  0.429
# 8              Jarrett Allen   C   22  BRK  12   5  26.7  3.7   5.4  0.677
# 9              Jarrett Allen   C   22  CLE  16   5  25.9  4.9   7.8  0.624
# 10           Al-Farouq Aminu  PF   30  ORL   2   0   8.0  0.5   0.5  1.000
#
#     ...  TOV%  USG%  OWS  DWS  WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 1   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 2   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 3   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 4   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 5   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 6   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 7   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 8   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 9   ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 10  ...   NaN   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
#
# [11 rows x 50 columns]

# %%
np.shape(df_combined)
# Out:
# (1671, 50)

# %%
# Obtener los valores únicos de la columna team_abbreviation
valores_unicos = df_combined['Team'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['MIA' 'MIL' 'NOP' 'SAS' 'PHO' 'MEM' 'BRK' 'CLE' 'ORL' 'LAL' 'POR' 'TOR'
#  'CHI' 'WAS' 'UTA' 'SAC' 'CHO' 'NYK' 'DEN' 'LAC' 'GSW' 'OKC' 'MIN' 'DET'
#  'DAL' 'IND' 'ATL' 'PHI' 'BOS' 'HOU']

# %%
df_combined.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Temp',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %%
df_combined.head()
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  TOV%  \
# 0   Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...   NaN
# 1       Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...   NaN
# 2       Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...   NaN
# 3        Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...   NaN
# 4  LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...   NaN
#
#    USG%  OWS  DWS  WS  WS/48  OBPM  DBPM  BPM  VORP
# 0   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 1   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 2   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 3   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
# 4   NaN  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# Se le agregan corchetes al principio y al final, dejando los valores de los equipos en el medio, a las columnas Team y TOTAL TEAM.

# %% [markdown]
# Esto es para no tener problemas de reconocimiento a la hora de guardar el CSV y enviarlo a SQL, debido a que los datos se separan con '/' en esas columnas.

# %%
df_combined
# Out:
#                  Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0      Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...
# 1          Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...
# 2          Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...
# 3           Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...
# 4     LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...
# ...                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 1666      Justin Minaya  SF   23  POR   4   0  22.3  1.8   5.8  0.304  ...
# 1667       Kobi Simmons  SG   25  CHO   5   0   5.6  0.2   1.2  0.167  ...
# 1668          Gabe York  SG   29  IND   3   0  18.7  2.7   7.0  0.381  ...
# 1669       RaiQuan Gray  PF   23  BRK   1   0  35.0  6.0  12.0  0.500  ...
# 1670      Jacob Gilyard  PG   24  MEM   1   0  41.0  1.0   3.0  0.333  ...
#
#       TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 1      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 2      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 3      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# 4      NaN   NaN  NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN
# ...    ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 1666  14.6  13.4 -0.2  0.1 -0.1 -0.067  -7.2  -1.9 -9.0  -0.2
# 1667  12.7  11.8  0.0  0.0  0.0  0.019  -1.0   0.1 -0.9   0.0
# 1668   0.0  16.4  0.1  0.0  0.1  0.091  -1.7  -1.8 -3.5   0.0
# 1669  23.7  21.4  0.0  0.0  0.1  0.106  -0.6  -1.4 -2.0   0.0
# 1670  40.0   5.1  0.0  0.1  0.1  0.079  -7.8   1.7 -6.1   0.0
#
# [1671 rows x 50 columns]

# %%
df_combined.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Temp',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# ## Ahora creare una player_id para todos los jugadores teniendo en cuenta que hay jugadores que se  repiten. A estos hay que asignarle la misma id cada vez.

# %%
# Obtén los jugadores únicos
playerss = df_combined['Player']

# Crea un diccionario para mapear nombres de jugadores a IDs
player_id_map = {player: idx + 1 for idx, player in enumerate(playerss)}

# Asigna IDs a los jugadores en el DataFrame
df_combined['player_id'] = df_combined['Player'].map(player_id_map)

# %%
np.shape(df_combined)
# Out:
# (1671, 51)

# %%
df_combined.isnull().sum()
# Out:
# Player          0
# Pos             0
# Age             0
# Team            0
# GP              0
# GS              0
# MP              0
# FG              0
# FGA             0
# FG%             0
# 3P              0
# 3PA             0
# 3P%             0
# 2P              0
# 2PA             0
# 2P%             0
# eFG%            0
# FT              0
# FTA             0
# FT%             0
# ORB             0
# DRB             0
# TRB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# PF              0
# PTS             0
# Temp            0
# PER          1204
# TS%          1205
# 3PAr         1205
# FTr          1205
# ORB%         1204
# DRB%         1204
# TRB%         1204
# AST%         1204
# STL%         1204
# BLK%         1204
# TOV%         1204
# USG%         1204
# OWS          1204
# DWS          1204
# WS           1204
# WS/48        1204
# OBPM         1204
# DBPM         1204
# BPM          1204
# VORP         1204
# player_id       0
# dtype: int64

# %%
df_combined.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Temp',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'player_id'],
#       dtype='object')

# %%
# Agrupamos por 'player_id' y verificamos si cada grupo tiene un solo nombre único en la columna 'Player'
validation = df_combined.groupby('player_id')['Player'].nunique()

# Filtramos para encontrar cualquier 'player_id' que tenga más de un nombre asociado
invalid_ids = validation[validation > 1]

if invalid_ids.empty:
    print("¡Éxito! Todos los player_id tienen un único nombre de jugador asignado.")
else:
    print("Se encontraron inconsistencias en los siguientes player_id:")
    print(invalid_ids)
# Out:
# ¡Éxito! Todos los player_id tienen un único nombre de jugador asignado.

# %%
df_combined.isnull().sum()
# Out:
# Player          0
# Pos             0
# Age             0
# Team            0
# GP              0
# GS              0
# MP              0
# FG              0
# FGA             0
# FG%             0
# 3P              0
# 3PA             0
# 3P%             0
# 2P              0
# 2PA             0
# 2P%             0
# eFG%            0
# FT              0
# FTA             0
# FT%             0
# ORB             0
# DRB             0
# TRB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# PF              0
# PTS             0
# Temp            0
# PER          1204
# TS%          1205
# 3PAr         1205
# FTr          1205
# ORB%         1204
# DRB%         1204
# TRB%         1204
# AST%         1204
# STL%         1204
# BLK%         1204
# TOV%         1204
# USG%         1204
# OWS          1204
# DWS          1204
# WS           1204
# WS/48        1204
# OBPM         1204
# DBPM         1204
# BPM          1204
# VORP         1204
# player_id       0
# dtype: int64

# %%
df_combined.head()
# Out:
#               Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  USG%  \
# 0   Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...   NaN
# 1       Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...   NaN
# 2       Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...   NaN
# 3        Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...   NaN
# 4  LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...   NaN
#
#    OWS  DWS  WS  WS/48  OBPM  DBPM  BPM  VORP  player_id
# 0  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN       1471
# 1  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN          2
# 2  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN       1274
# 3  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN       1243
# 4  NaN  NaN NaN    NaN   NaN   NaN  NaN   NaN        494
#
# [5 rows x 51 columns]

# %% [markdown]
# Se modifica el formato de las ids.

# %%
df_combined['player_id'] = df_combined['player_id'].astype('int')

# %% [markdown]
# ### Se crea una llave primaria compuesta unificada con la id de jugadores y la temporada en la que jugó.

# %% [markdown]
# Esto se decidió para que la tabla de hechos tenga todas ids unicas.

# %%
# Crear una nueva columna 'primary_key' que combine 'id' y 'Temp'
df_combined['primary_key_composed'] = df_combined['player_id'].astype(str) + "_" + df_combined['Temp'].astype(str) + "_" + df_combined['Team'].astype(str)

# Verificar las primeras filas de la tabla con la nueva columna
print(df_combined[['player_id', 'Temp', 'primary_key_composed']].head())
# Out:
#    player_id  Temp primary_key_composed
# 0       1471  2021        1471_2021_MIA
# 1          2  2021           2_2021_MIL
# 2       1274  2021        1274_2021_NOP
# 3       1243  2021        1243_2021_MIA
# 4        494  2021         494_2021_SAS

# %%
np.shape(df_combined)
# Out:
# (1671, 52)

# %% [markdown]
# Verificamos el exito de nuestro codigo, observando los duplicados.

# %%
# Verificar si hay duplicados en la columna 'id'
duplicated_ids = df_combined[df_combined['primary_key_composed'].duplicated(keep=False)]

# Mostrar los duplicados encontrados (si existen)
if not duplicated_ids.empty:
    print("Se encontraron los siguientes duplicados en la columna 'primary_key_composed':")
    print(duplicated_ids)
else:
    print("No se encontraron duplicados en la columna 'primary_key_composed'.")
# Out:
# No se encontraron duplicados en la columna 'primary_key_composed'.

# %%
df_combined
# Out:
#                  Player Pos  Age Team  GP  GS    MP   FG   FGA    FG%  ...  \
# 0      Precious Achiuwa  PF   21  MIA  28   2  14.6  2.6   4.4  0.590  ...
# 1          Jaylen Adams  PG   24  MIL   6   0   2.8  0.2   1.3  0.125  ...
# 2          Steven Adams   C   27  NOP  27  27  28.1  3.5   5.8  0.603  ...
# 3           Bam Adebayo   C   23  MIA  26  26  33.6  7.4  12.9  0.573  ...
# 4     LaMarcus Aldridge   C   35  SAS  18  18  26.7  5.9  12.5  0.476  ...
# ...                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 1666      Justin Minaya  SF   23  POR   4   0  22.3  1.8   5.8  0.304  ...
# 1667       Kobi Simmons  SG   25  CHO   5   0   5.6  0.2   1.2  0.167  ...
# 1668          Gabe York  SG   29  IND   3   0  18.7  2.7   7.0  0.381  ...
# 1669       RaiQuan Gray  PF   23  BRK   1   0  35.0  6.0  12.0  0.500  ...
# 1670      Jacob Gilyard  PG   24  MEM   1   0  41.0  1.0   3.0  0.333  ...
#
#       OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  player_id  \
# 0     NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN       1471
# 1     NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN          2
# 2     NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN       1274
# 3     NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN       1243
# 4     NaN  NaN  NaN    NaN   NaN   NaN  NaN   NaN        494
# ...   ...  ...  ...    ...   ...   ...  ...   ...        ...
# 1666 -0.2  0.1 -0.1 -0.067  -7.2  -1.9 -9.0  -0.2       1667
# 1667  0.0  0.0  0.0  0.019  -1.0   0.1 -0.9   0.0       1668
# 1668  0.1  0.0  0.1  0.091  -1.7  -1.8 -3.5   0.0       1669
# 1669  0.0  0.0  0.1  0.106  -0.6  -1.4 -2.0   0.0       1670
# 1670  0.0  0.1  0.1  0.079  -7.8   1.7 -6.1   0.0       1671
#
#       primary_key_composed
# 0            1471_2021_MIA
# 1               2_2021_MIL
# 2            1274_2021_NOP
# 3            1243_2021_MIA
# 4             494_2021_SAS
# ...                    ...
# 1666         1667_2023_POR
# 1667         1668_2023_CHO
# 1668         1669_2023_IND
# 1669         1670_2023_BRK
# 1670         1671_2023_MEM
#
# [1671 rows x 52 columns]

# %% [markdown]
# Reordenamos las columnas en base a una estandarización propuesta por el equipo encargado de la arquitectura.

# %%
df_combined = df_combined[['primary_key_composed', 'player_id', 'Player', 'Pos', 'Age', 'Team', 'GP', 'GS', 'MP', 'FG', 'FGA', 'FG%',
            '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
            'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Temp']]

# %%
df_combined = df_combined.rename(columns={'Temp': 'season_id'})
df_combined = df_combined.rename(columns={'Team': 'team_abbreviation'})
df_combined = df_combined.rename(columns={'Player': 'player_name'})
df_combined = df_combined.rename(columns={'Pos': 'position'})
df_combined = df_combined.rename(columns={'Age': 'age'})

# %%
print(df_combined.dtypes)
# Out:
# primary_key_composed     object
# player_id                 int64
# player_name              object
# position                 object
# age                       int64
# team_abbreviation        object
# GP                        int64
# GS                        int64
# MP                      float64
# FG                      float64
# FGA                     float64
# FG%                     float64
# 3P                      float64
# 3PA                     float64
# 3P%                     float64
# 2P                      float64
# 2PA                     float64
# 2P%                     float64
# eFG%                    float64
# FT                      float64
# FTA                     float64
# FT%                     float64
# ORB                     float64
# DRB                     float64
# TRB                     float64
# AST                     float64
# STL                     float64
# BLK                     float64
# TOV                     float64
# PF                      float64
# PTS                     float64
# season_id                 int64
# dtype: object

# %%
np.shape(df_combined)
# Out:
# (1671, 32)

# %%
# Filtrar filas donde 'Team' es 'TOT'
df_tot = df_combined[df_combined['team_abbreviation'] == 'TOT']

# Mostrar el resultado
print(df_tot)
# Out:
# Empty DataFrame
# Columns: [primary_key_composed, player_id, player_name, position, age, team_abbreviation, GP, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, season_id]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Filtrar filas donde 'Team' es 'TOT'
df_tot = df_combined[df_combined['team_abbreviation'] == 'TOT']

# Mostrar el resultado
print(df_tot)
# Out:
# Empty DataFrame
# Columns: [primary_key_composed, player_id, player_name, position, age, team_abbreviation, GP, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, season_id]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# Se guarda la tabla de hechos final.

# %%
df_combined.to_csv('player_final_merged_with_stats_sinTOT.csv', index=False)
