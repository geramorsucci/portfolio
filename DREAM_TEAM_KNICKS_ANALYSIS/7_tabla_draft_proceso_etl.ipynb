# %% [markdown]
# # Tabla Draft

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Carga de draft_history

# %%
draft_history = pd.read_csv('draft_history.csv')

# %%
np.shape(draft_history)
# Out:
# (7990, 14)

# %% [markdown]
# ### Vista preeliminar de los datos

# %%
draft_history.head()
# Out:
#    person_id       player_name  season  round_number  round_pick  \
# 0      79299  Clifton McNeeley    1947             1           1
# 1      78109        Glen Selbo    1947             1           2
# 2      76649      Eddie Ehlers    1947             1           3
# 3      79302        Walt Dropo    1947             1           4
# 4      77048        Dick Holub    1947             1           5
#
#    overall_pick draft_type     team_id   team_city     team_name  \
# 0             1      Draft  1610610031  Pittsburgh       Ironmen
# 1             2      Draft  1610610035     Toronto       Huskies
# 2             3      Draft  1610612738      Boston       Celtics
# 3             4      Draft  1610610032  Providence  Steamrollers
# 4             5      Draft  1610612752    New York        Knicks
#
#   team_abbreviation          organization   organization_type  \
# 0               PIT         Texas-El Paso  College/University
# 1               HUS             Wisconsin  College/University
# 2               BOS                Purdue  College/University
# 3               PRO           Connecticut  College/University
# 4               NYK  Long Island-Brooklyn  College/University
#
#    player_profile_flag
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    1

# %% [markdown]
# ### Valores nulos

# %%
draft_history.isnull().sum()
# Out:
# person_id               0
# player_name             0
# season                  0
# round_number            0
# round_pick              0
# overall_pick            0
# draft_type              0
# team_id                 0
# team_city               0
# team_name               0
# team_abbreviation       0
# organization           19
# organization_type      19
# player_profile_flag     0
# dtype: int64

# %% [markdown]
# ### Tipo de datos de las columnas

# %%
draft_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7990 entries, 0 to 7989
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   person_id            7990 non-null   int64
#  1   player_name          7990 non-null   object
#  2   season               7990 non-null   int64
#  3   round_number         7990 non-null   int64
#  4   round_pick           7990 non-null   int64
#  5   overall_pick         7990 non-null   int64
#  6   draft_type           7990 non-null   object
#  7   team_id              7990 non-null   int64
#  8   team_city            7990 non-null   object
#  9   team_name            7990 non-null   object
#  10  team_abbreviation    7990 non-null   object
#  11  organization         7971 non-null   object
#  12  organization_type    7971 non-null   object
#  13  player_profile_flag  7990 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 874.0+ KB

# %%
season_unique = draft_history['season'].unique()
print(season_unique)
# Out:
# [1947 1948 1949 1950 1951 1952 1953 1954 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976
#  1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990
#  1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012 2013 2015 2016 2017 2018 2019
#  2020 2021 2022 2023]

# %% [markdown]
# ### Filtrado por season a partir de 2003 (jugadores activos)

# %%
# Filtro el dataframe a partir de 2003 y lo guardo en un nuevo dataframe.
draft_history_season=draft_history[draft_history['season'] >= 2003]

# %%
draft_history_season.head()
# Out:
#       person_id      player_name  season  round_number  round_pick  \
# 6797       2544     LeBron James    2003             1           1
# 6798       2545    Darko Milicic    2003             1           2
# 6799       2546  Carmelo Anthony    2003             1           3
# 6800       2547       Chris Bosh    2003             1           4
# 6801       2548      Dwyane Wade    2003             1           5
#
#       overall_pick draft_type     team_id  team_city  team_name  \
# 6797             1      Draft  1610612739  Cleveland  Cavaliers
# 6798             2      Draft  1610612765    Detroit    Pistons
# 6799             3      Draft  1610612743     Denver    Nuggets
# 6800             4      Draft  1610612761    Toronto    Raptors
# 6801             5      Draft  1610612748      Miami       Heat
#
#      team_abbreviation              organization   organization_type  \
# 6797               CLE  Saint Vincent-Saint Mary         High School
# 6798               DET         KK Vrsac (Serbia)     Other Team/Club
# 6799               DEN                  Syracuse  College/University
# 6800               TOR              Georgia Tech  College/University
# 6801               MIA                 Marquette  College/University
#
#       player_profile_flag
# 6797                    1
# 6798                    1
# 6799                    1
# 6800                    1
# 6801                    1

# %% [markdown]
# ### Reviso los valores nulos

# %%
draft_history_season.isnull().sum()
# Out:
# person_id              0
# player_name            0
# season                 0
# round_number           0
# round_pick             0
# overall_pick           0
# draft_type             0
# team_id                0
# team_city              0
# team_name              0
# team_abbreviation      0
# organization           2
# organization_type      2
# player_profile_flag    0
# dtype: int64

# %%
draft_history_season = draft_history_season.fillna(0)

# %% [markdown]
# ### N° de filas y columnas despues del filtro de season

# %%
np.shape(draft_history_season)
# Out:
# (1193, 14)

# %% [markdown]
# ### Explicacion de las columnas:

# %% [markdown]
# round_number: Indica el número de la ronda en la que un jugador fue seleccionado durante el Draft. El Draft de la NBA tiene varias rondas, y cada ronda tiene un conjunto de selecciones.
#
# round_pick: Se refiere al número específico del pick (elección) dentro de una ronda en la que un jugador fue seleccionado. Por ejemplo, el "round_pick" 5 en la primera ronda significa que el jugador fue el quinto en ser elegido en esa ronda.
#
# overall_pick: Este es el número total de la elección en el Draft, contando todas las rondas. Por ejemplo, el "overall_pick" 15 significa que el jugador fue el 15º elegido en el Draft, sin importar en qué ronda.
#
# draft_type: Especifica el tipo de Draft. Puede referirse al Draft general, como el Draft de la NBA, o a un Draft específico como el Draft de la NBA de 2024.
#
# organization: Indica el equipo de la NBA que seleccionó al jugador en el Draft. Esto muestra qué equipo tiene los derechos sobre el jugador seleccionado.
#
# organization_type: Se refiere al tipo de organización que está realizando la selección. En el contexto del Draft de la NBA, esto generalmente se refiere a los equipos de la NBA.
#
# player_profile_flag: Es una bandera o indicador que puede mostrar si hay información adicional disponible sobre el perfil del jugador. Esto podría incluir detalles como si el jugador ha sido seleccionado en el Draft, si tiene alguna nota especial o si su perfil está completo.

# %% [markdown]
# ## Eliminacion de columnas innecesarias

# %%
draft_history_season_columns_drop = ['draft_type', 'player_profile_flag']
draft_history_season_clear = draft_history_season.drop(columns=draft_history_season_columns_drop)

# %% [markdown]
# ### Seteo de corchetes para evitar problemas debido del uso del / dentro de los valores de la columna organization_type

# %%
draft_history_season_clear['organization_type'] = draft_history_season_clear['organization_type'].apply(lambda x: f"[{x}]")

# %%
draft_history_season_clear.rename(columns={'person_id': 'draft_id'}, inplace=True)

# %%
draft_history_season_clear.rename(columns={'season': 'draft_season'}, inplace=True)

# %%
draft_history_season_clear.head()
# Out:
#       draft_id      player_name  draft_season  round_number  round_pick  \
# 6797      2544     LeBron James          2003             1           1
# 6798      2545    Darko Milicic          2003             1           2
# 6799      2546  Carmelo Anthony          2003             1           3
# 6800      2547       Chris Bosh          2003             1           4
# 6801      2548      Dwyane Wade          2003             1           5
#
#       overall_pick     team_id  team_city  team_name team_abbreviation  \
# 6797             1  1610612739  Cleveland  Cavaliers               CLE
# 6798             2  1610612765    Detroit    Pistons               DET
# 6799             3  1610612743     Denver    Nuggets               DEN
# 6800             4  1610612761    Toronto    Raptors               TOR
# 6801             5  1610612748      Miami       Heat               MIA
#
#                   organization     organization_type
# 6797  Saint Vincent-Saint Mary         [High School]
# 6798         KK Vrsac (Serbia)     [Other Team/Club]
# 6799                  Syracuse  [College/University]
# 6800              Georgia Tech  [College/University]
# 6801                 Marquette  [College/University]

# %% [markdown]
# # Carga de draft_combine_stats

# %%
draft_stats = pd.read_csv('draft_combine_stats.csv')

# %%
np.shape(draft_stats)
# Out:
# (1202, 47)

# %% [markdown]
# ### Vista preeliminar de los datos

# %%
draft_stats.head()
# Out:
#    season  player_id first_name   last_name        player_name position  \
# 0    2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1    2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2    2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3    2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4    2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
#
#    height_wo_shoes height_wo_shoes_ft_in  height_w_shoes height_w_shoes_ft_in  \
# 0            83.50             6' 11.5''             NaN                  NaN
# 1            74.25             6' 2.25''             NaN                  NaN
# 2            75.50              6' 3.5''             NaN                  NaN
# 3            80.25             6' 8.25''             NaN                  NaN
# 4            75.00                6' 3''             NaN                  NaN
#
#    ...  spot_nba_break_right  spot_nba_corner_right  \
# 0  ...                   NaN                    NaN
# 1  ...                   NaN                    NaN
# 2  ...                   NaN                    NaN
# 3  ...                   NaN                    NaN
# 4  ...                   NaN                    NaN
#
#   off_drib_fifteen_break_left  off_drib_fifteen_top_key  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   off_drib_fifteen_break_right  off_drib_college_break_left  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    off_drib_college_top_key  off_drib_college_break_right  on_move_fifteen  \
# 0                       NaN                           NaN              NaN
# 1                       NaN                           NaN              NaN
# 2                       NaN                           NaN              NaN
# 3                       NaN                           NaN              NaN
# 4                       NaN                           NaN              NaN
#
#    on_move_college
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Tipo de datos del dataframe

# %%
draft_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202 entries, 0 to 1201
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        1202 non-null   int64
#  1   player_id                     1202 non-null   int64
#  2   first_name                    1202 non-null   object
#  3   last_name                     1202 non-null   object
#  4   player_name                   1202 non-null   object
#  5   position                      1197 non-null   object
#  6   height_wo_shoes               1153 non-null   float64
#  7   height_wo_shoes_ft_in         1153 non-null   object
#  8   height_w_shoes                1008 non-null   float64
#  9   height_w_shoes_ft_in          1008 non-null   object
#  10  weight                        1152 non-null   float64
#  11  wingspan                      1153 non-null   float64
#  12  wingspan_ft_in                1153 non-null   object
#  13  standing_reach                1152 non-null   float64
#  14  standing_reach_ft_in          1152 non-null   object
#  15  body_fat_pct                  1003 non-null   float64
#  16  hand_length                   719 non-null    float64
#  17  hand_width                    719 non-null    float64
#  18  standing_vertical_leap        1017 non-null   float64
#  19  max_vertical_leap             1017 non-null   float64
#  20  lane_agility_time             1008 non-null   float64
#  21  modified_lane_agility_time    411 non-null    float64
#  22  three_quarter_sprint          1012 non-null   float64
#  23  bench_press                   808 non-null    float64
#  24  spot_fifteen_corner_left      74 non-null     object
#  25  spot_fifteen_break_left       76 non-null     object
#  26  spot_fifteen_top_key          76 non-null     object
#  27  spot_fifteen_break_right      76 non-null     object
#  28  spot_fifteen_corner_right     76 non-null     object
#  29  spot_college_corner_left      245 non-null    object
#  30  spot_college_break_left       166 non-null    object
#  31  spot_college_top_key          166 non-null    object
#  32  spot_college_break_right      166 non-null    object
#  33  spot_college_corner_right     166 non-null    object
#  34  spot_nba_corner_left          217 non-null    object
#  35  spot_nba_break_left           217 non-null    object
#  36  spot_nba_top_key              217 non-null    object
#  37  spot_nba_break_right          217 non-null    object
#  38  spot_nba_corner_right         217 non-null    object
#  39  off_drib_fifteen_break_left   166 non-null    object
#  40  off_drib_fifteen_top_key      166 non-null    object
#  41  off_drib_fifteen_break_right  166 non-null    object
#  42  off_drib_college_break_left   110 non-null    object
#  43  off_drib_college_top_key      31 non-null     object
#  44  off_drib_college_break_right  31 non-null     object
#  45  on_move_fifteen               148 non-null    object
#  46  on_move_college               116 non-null    object
# dtypes: float64(14), int64(2), object(31)
# memory usage: 441.5+ KB

# %% [markdown]
# ### Filtro por season a partir del 2003 (jugadores activos)

# %%
# Filtro el datafrme a partir del 2003 y lo guardo en un nuevo dataframe.
draft_stats_season=draft_stats[draft_stats['season'] >= 2003]

# %%
draft_stats_season.head()
# Out:
#     season  player_id first_name last_name      player_name position  \
# 78    2004       2754       Tony     Allen       Tony Allen       SG
# 79    2004       2772     Trevor     Ariza     Trevor Ariza    SG-SF
# 80    2004       2857      Andre   Barrett    Andre Barrett       PG
# 81    2004     101138    Brandon      Bass     Brandon Bass       PF
# 82    2004       2740     Andris  Biedrins  Andris Biedrins        C
#
#     height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# 78            75.50              6' 3.5''           76.25
# 79            79.00                6' 7''           80.25
# 80            68.75             5' 8.75''           69.75
# 81            78.25             6' 6.25''           79.25
# 82              NaN                   NaN             NaN
#
#    height_w_shoes_ft_in  ...  spot_nba_break_right  spot_nba_corner_right  \
# 78            6' 4.25''  ...                   NaN                    NaN
# 79            6' 8.25''  ...                   NaN                    NaN
# 80            5' 9.75''  ...                   NaN                    NaN
# 81            6' 7.25''  ...                   NaN                    NaN
# 82                  NaN  ...                   NaN                    NaN
#
#    off_drib_fifteen_break_left  off_drib_fifteen_top_key  \
# 78                         NaN                       NaN
# 79                         NaN                       NaN
# 80                         NaN                       NaN
# 81                         NaN                       NaN
# 82                         NaN                       NaN
#
#    off_drib_fifteen_break_right  off_drib_college_break_left  \
# 78                          NaN                          NaN
# 79                          NaN                          NaN
# 80                          NaN                          NaN
# 81                          NaN                          NaN
# 82                          NaN                          NaN
#
#     off_drib_college_top_key  off_drib_college_break_right  on_move_fifteen  \
# 78                       NaN                           NaN              NaN
# 79                       NaN                           NaN              NaN
# 80                       NaN                           NaN              NaN
# 81                       NaN                           NaN              NaN
# 82                       NaN                           NaN              NaN
#
#     on_move_college
# 78              NaN
# 79              NaN
# 80              NaN
# 81              NaN
# 82              NaN
#
# [5 rows x 47 columns]

# %%
np.shape(draft_stats_season)
# Out:
# (1124, 47)

# %% [markdown]
# ### Visualizar los valores nulos

# %%
draft_stats_season.isnull().sum()
# Out:
# season                             0
# player_id                          0
# first_name                         0
# last_name                          0
# player_name                        0
# position                           5
# height_wo_shoes                   49
# height_wo_shoes_ft_in             49
# height_w_shoes                   116
# height_w_shoes_ft_in             116
# weight                            50
# wingspan                          49
# wingspan_ft_in                    49
# standing_reach                    50
# standing_reach_ft_in              50
# body_fat_pct                     197
# hand_length                      405
# hand_width                       405
# standing_vertical_leap           184
# max_vertical_leap                184
# lane_agility_time                192
# modified_lane_agility_time       713
# three_quarter_sprint             189
# bench_press                      393
# spot_fifteen_corner_left        1050
# spot_fifteen_break_left         1048
# spot_fifteen_top_key            1048
# spot_fifteen_break_right        1048
# spot_fifteen_corner_right       1048
# spot_college_corner_left         879
# spot_college_break_left          958
# spot_college_top_key             958
# spot_college_break_right         958
# spot_college_corner_right        958
# spot_nba_corner_left             907
# spot_nba_break_left              907
# spot_nba_top_key                 907
# spot_nba_break_right             907
# spot_nba_corner_right            907
# off_drib_fifteen_break_left      958
# off_drib_fifteen_top_key         958
# off_drib_fifteen_break_right     958
# off_drib_college_break_left     1014
# off_drib_college_top_key        1093
# off_drib_college_break_right    1093
# on_move_fifteen                  976
# on_move_college                 1008
# dtype: int64

# %%
player_sin_position = draft_stats_season[draft_stats_season['position'].isnull()]
player_sin_position.head()
# Out:
#      season  player_id first_name last_name      player_name position  \
# 189    2005     101122      Danny   Granger    Danny Granger      NaN
# 314    2007     201146   Jianlian        Yi      Jianlian Yi      NaN
# 948    2019    1629631   De'Andre    Hunter  De'Andre Hunter      NaN
# 967    2019    1629643      Chuma     Okeke      Chuma Okeke      NaN
# 984    2019    1629681    Killian    Tillie   Killian Tillie      NaN
#
#      height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# 189             79.5              6' 7.5''            80.5
# 314              NaN                   NaN             NaN
# 948              NaN                   NaN             NaN
# 967              NaN                   NaN             NaN
# 984              NaN                   NaN             NaN
#
#     height_w_shoes_ft_in  ...  spot_nba_break_right  spot_nba_corner_right  \
# 189             6' 8.5''  ...                   NaN                    NaN
# 314                  NaN  ...                   NaN                    NaN
# 948                  NaN  ...                   NaN                    NaN
# 967                  NaN  ...                   NaN                    NaN
# 984                  NaN  ...                   NaN                    NaN
#
#     off_drib_fifteen_break_left  off_drib_fifteen_top_key  \
# 189                         NaN                       NaN
# 314                         NaN                       NaN
# 948                         NaN                       NaN
# 967                         NaN                       NaN
# 984                         NaN                       NaN
#
#     off_drib_fifteen_break_right  off_drib_college_break_left  \
# 189                          NaN                          NaN
# 314                          NaN                          NaN
# 948                          NaN                          NaN
# 967                          NaN                          NaN
# 984                          NaN                          NaN
#
#      off_drib_college_top_key  off_drib_college_break_right  on_move_fifteen  \
# 189                       NaN                           NaN              NaN
# 314                       NaN                           NaN              NaN
# 948                       NaN                           NaN              NaN
# 967                       NaN                           NaN              NaN
# 984                       NaN                           NaN              NaN
#
#      on_move_college
# 189              NaN
# 314              NaN
# 948              NaN
# 967              NaN
# 984              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Tratado de nulos
#     Se decide trabajar hasta la columna three_quarter_corner_left ya que las demas columnas superan el 50% de valores nulos

# %%
columnas_a_rellenar_con_0 = [
    'position', 'height_wo_shoes', 'height_wo_shoes_ft_in', 'height_w_shoes',
    'height_w_shoes_ft_in', 'weight', 'wingspan', 'wingspan_ft_in',
    'standing_reach', 'standing_reach_ft_in', 'body_fat_pct',
    'hand_length', 'hand_width', 'standing_vertical_leap',
    'max_vertical_leap', 'lane_agility_time', 'modified_lane_agility_time',
    'three_quarter_sprint'
]

# Rellenar valores nulos con ceros para las columnas restantes
for columna in columnas_a_rellenar_con_0:
    draft_stats_season[columna] = draft_stats_season[columna].fillna(0)
# Out:
# C:\Users\Agus\AppData\Local\Temp\ipykernel_11544\482357495.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   draft_stats_season[columna] = draft_stats_season[columna].fillna(0)

# %% [markdown]
# ### Visualizacion del dataframe

# %%
draft_stats_season.head()
# Out:
#     season  player_id first_name last_name      player_name position  \
# 78    2004       2754       Tony     Allen       Tony Allen       SG
# 79    2004       2772     Trevor     Ariza     Trevor Ariza    SG-SF
# 80    2004       2857      Andre   Barrett    Andre Barrett       PG
# 81    2004     101138    Brandon      Bass     Brandon Bass       PF
# 82    2004       2740     Andris  Biedrins  Andris Biedrins        C
#
#     height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# 78            75.50              6' 3.5''           76.25
# 79            79.00                6' 7''           80.25
# 80            68.75             5' 8.75''           69.75
# 81            78.25             6' 6.25''           79.25
# 82             0.00                     0            0.00
#
#    height_w_shoes_ft_in  ...  spot_nba_break_right  spot_nba_corner_right  \
# 78            6' 4.25''  ...                   NaN                    NaN
# 79            6' 8.25''  ...                   NaN                    NaN
# 80            5' 9.75''  ...                   NaN                    NaN
# 81            6' 7.25''  ...                   NaN                    NaN
# 82                    0  ...                   NaN                    NaN
#
#    off_drib_fifteen_break_left  off_drib_fifteen_top_key  \
# 78                         NaN                       NaN
# 79                         NaN                       NaN
# 80                         NaN                       NaN
# 81                         NaN                       NaN
# 82                         NaN                       NaN
#
#    off_drib_fifteen_break_right  off_drib_college_break_left  \
# 78                          NaN                          NaN
# 79                          NaN                          NaN
# 80                          NaN                          NaN
# 81                          NaN                          NaN
# 82                          NaN                          NaN
#
#     off_drib_college_top_key  off_drib_college_break_right  on_move_fifteen  \
# 78                       NaN                           NaN              NaN
# 79                       NaN                           NaN              NaN
# 80                       NaN                           NaN              NaN
# 81                       NaN                           NaN              NaN
# 82                       NaN                           NaN              NaN
#
#     on_move_college
# 78              NaN
# 79              NaN
# 80              NaN
# 81              NaN
# 82              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Eliminacion de las columnas con NA

# %%
draft_stats_season_clear = draft_stats_season.dropna(axis=1)

# %% [markdown]
# ### Visualizar el dataframe limpio

# %%
draft_stats_season_clear.head()
# Out:
#     season  player_id first_name last_name      player_name position  \
# 78    2004       2754       Tony     Allen       Tony Allen       SG
# 79    2004       2772     Trevor     Ariza     Trevor Ariza    SG-SF
# 80    2004       2857      Andre   Barrett    Andre Barrett       PG
# 81    2004     101138    Brandon      Bass     Brandon Bass       PF
# 82    2004       2740     Andris  Biedrins  Andris Biedrins        C
#
#     height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# 78            75.50              6' 3.5''           76.25
# 79            79.00                6' 7''           80.25
# 80            68.75             5' 8.75''           69.75
# 81            78.25             6' 6.25''           79.25
# 82             0.00                     0            0.00
#
#    height_w_shoes_ft_in  ...  standing_reach  standing_reach_ft_in  \
# 78            6' 4.25''  ...           102.0                8' 6''
# 79            6' 8.25''  ...           107.5             8' 11.5''
# 80            5' 9.75''  ...            92.0                7' 8''
# 81            6' 7.25''  ...           106.5             8' 10.5''
# 82                    0  ...             0.0                     0
#
#    body_fat_pct  hand_length hand_width  standing_vertical_leap  \
# 78          6.7          0.0        0.0                    31.5
# 79          8.0          0.0        0.0                    29.5
# 80          6.7          0.0        0.0                    29.0
# 81          9.3          0.0        0.0                    31.5
# 82          9.3          0.0        0.0                     0.0
#
#     max_vertical_leap  lane_agility_time  modified_lane_agility_time  \
# 78               36.5              10.70                         0.0
# 79               32.0              11.63                         0.0
# 80               34.5              10.63                         0.0
# 81               33.0              11.61                         0.0
# 82                0.0               0.00                         0.0
#
#     three_quarter_sprint
# 78                  3.19
# 79                  3.29
# 80                  3.08
# 81                  3.24
# 82                  0.00
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Visualizar filas y columnas

# %%
np.shape(draft_stats_season_clear)
# Out:
# (1124, 23)

# %% [markdown]
# ### Revisar valores nulos

# %%
draft_stats_season_clear.isnull().sum()
# Out:
# season                        0
# player_id                     0
# first_name                    0
# last_name                     0
# player_name                   0
# position                      0
# height_wo_shoes               0
# height_wo_shoes_ft_in         0
# height_w_shoes                0
# height_w_shoes_ft_in          0
# weight                        0
# wingspan                      0
# wingspan_ft_in                0
# standing_reach                0
# standing_reach_ft_in          0
# body_fat_pct                  0
# hand_length                   0
# hand_width                    0
# standing_vertical_leap        0
# max_vertical_leap             0
# lane_agility_time             0
# modified_lane_agility_time    0
# three_quarter_sprint          0
# dtype: int64

# %%
# Borrar duplicados basados en la columna 'player_id'
draft_stats_season_clear_sin_duplicados = draft_stats_season_clear.drop_duplicates(subset=['player_id'])

# Mostrar las primeras filas del DataFrame sin duplicados
print("Primeras filas del DataFrame sin duplicados:")
print(draft_stats_season_clear_sin_duplicados.head())
# Out:
# Primeras filas del DataFrame sin duplicados:
#     season  player_id first_name last_name      player_name position  \
# 78    2004       2754       Tony     Allen       Tony Allen       SG
# 79    2004       2772     Trevor     Ariza     Trevor Ariza    SG-SF
# 80    2004       2857      Andre   Barrett    Andre Barrett       PG
# 81    2004     101138    Brandon      Bass     Brandon Bass       PF
# 82    2004       2740     Andris  Biedrins  Andris Biedrins        C
#
#     height_wo_shoes height_wo_shoes_ft_in  height_w_shoes  \
# 78            75.50              6' 3.5''           76.25
# 79            79.00                6' 7''           80.25
# 80            68.75             5' 8.75''           69.75
# 81            78.25             6' 6.25''           79.25
# 82             0.00                     0            0.00
#
#    height_w_shoes_ft_in  ...  standing_reach  standing_reach_ft_in  \
# 78            6' 4.25''  ...           102.0                8' 6''
# 79            6' 8.25''  ...           107.5             8' 11.5''
# 80            5' 9.75''  ...            92.0                7' 8''
# 81            6' 7.25''  ...           106.5             8' 10.5''
# 82                    0  ...             0.0                     0
#
#    body_fat_pct  hand_length hand_width  standing_vertical_leap  \
# 78          6.7          0.0        0.0                    31.5
# 79          8.0          0.0        0.0                    29.5
# 80          6.7          0.0        0.0                    29.0
# 81          9.3          0.0        0.0                    31.5
# 82          9.3          0.0        0.0                     0.0
#
#     max_vertical_leap  lane_agility_time  modified_lane_agility_time  \
# 78               36.5              10.70                         0.0
# 79               32.0              11.63                         0.0
# 80               34.5              10.63                         0.0
# 81               33.0              11.61                         0.0
# 82                0.0               0.00                         0.0
#
#     three_quarter_sprint
# 78                  3.19
# 79                  3.29
# 80                  3.08
# 81                  3.24
# 82                  0.00
#
# [5 rows x 23 columns]

# %%
draft_stats_season_clear.rename(columns={'player_id': 'draft_id'}, inplace=True)
# Out:
# C:\Users\Agus\AppData\Local\Temp\ipykernel_11544\4003088987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   draft_stats_season_clear.rename(columns={'player_id': 'draft_id'}, inplace=True)

# %%
draft_stats_season_clear.rename(columns={'season': 'draft_season'}, inplace=True)
# Out:
# C:\Users\Agus\AppData\Local\Temp\ipykernel_11544\358399204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   draft_stats_season_clear.rename(columns={'season': 'draft_season'}, inplace=True)

# %% [markdown]
# ### Merge entre draft_history y draft_combine_stats

# %%
draft_stats_season_clear_columnas_merge = draft_stats_season_clear[[ 'draft_id',
    'position',
    'height_wo_shoes',
    'height_wo_shoes_ft_in',
    'height_w_shoes',
    'height_w_shoes_ft_in',
    'weight',
    'wingspan',
    'wingspan_ft_in',
    'standing_reach',
    'standing_reach_ft_in',
    'body_fat_pct',
    'hand_length',
    'hand_width',
    'standing_vertical_leap',
    'max_vertical_leap',
    'lane_agility_time',
    'modified_lane_agility_time',
    'three_quarter_sprint'
]]

# %% [markdown]
# ### Merge entre draft_history y draft_stats

# %%
draft_completo = pd.merge(draft_history_season_clear, draft_stats_season_clear_columnas_merge, on='draft_id', how='inner')

# %% [markdown]
# ### Ver el nuevo dataframe

# %%
draft_completo.head()
# Out:
#    draft_id       player_name  draft_season  round_number  round_pick  \
# 0      2730     Dwight Howard          2004             1           1
# 1      2731      Emeka Okafor          2004             1           2
# 2      2732        Ben Gordon          2004             1           3
# 3      2733  Shaun Livingston          2004             1           4
# 4      2734      Devin Harris          2004             1           5
#
#    overall_pick     team_id    team_city team_name team_abbreviation  ...  \
# 0             1  1610612753      Orlando     Magic               ORL  ...
# 1             2  1610612766    Charlotte   Bobcats               CHA  ...
# 2             3  1610612741      Chicago     Bulls               CHI  ...
# 3             4  1610612746  Los Angeles  Clippers               LAC  ...
# 4             5  1610612764   Washington   Wizards               WAS  ...
#
#   standing_reach standing_reach_ft_in body_fat_pct  hand_length hand_width  \
# 0          111.5             9' 3.5''         10.5          0.0        0.0
# 1          110.5             9' 2.5''          5.3          0.0        0.0
# 2           99.0               8' 3''          5.3          0.0        0.0
# 3          105.5             8' 9.5''          6.7          0.0        0.0
# 4           98.5             8' 2.5''          5.3          0.0        0.0
#
#    standing_vertical_leap max_vertical_leap  lane_agility_time  \
# 0                    30.5              35.5              11.21
# 1                    31.5              34.0              12.32
# 2                    31.5              37.5              11.28
# 3                    26.5              30.0              10.72
# 4                    30.5              37.0              11.03
#
#    modified_lane_agility_time three_quarter_sprint
# 0                         0.0                 3.14
# 1                         0.0                 3.15
# 2                         0.0                 3.19
# 3                         0.0                 3.23
# 4                         0.0                 3.19
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Ver filas y columnas

# %%
np.shape(draft_completo)
# Out:
# (682, 30)

# %% [markdown]
# ### Chequeo de duplicados

# %%
duplicados = draft_completo.duplicated(keep=False)

# Filtra las filas duplicadas
datos_duplicados = draft_completo[duplicados]
print(datos_duplicados)
# Out:
# Empty DataFrame
# Columns: [draft_id, player_name, draft_season, round_number, round_pick, overall_pick, team_id, team_city, team_name, team_abbreviation, organization, organization_type, position, height_wo_shoes, height_wo_shoes_ft_in, height_w_shoes, height_w_shoes_ft_in, weight, wingspan, wingspan_ft_in, standing_reach, standing_reach_ft_in, body_fat_pct, hand_length, hand_width, standing_vertical_leap, max_vertical_leap, lane_agility_time, modified_lane_agility_time, three_quarter_sprint]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Verificar duplicados basados en la columna 'player_id'
duplicados_player_id = draft_completo.duplicated(subset=['draft_id'])

# Mostrar las filas duplicadas basadas en 'player_id'
draft_completo[duplicados_player_id]
# Out:
#      draft_id           player_name  draft_season  round_number  round_pick  \
# 456   1629021         Moritz Wagner          2018             1          25
# 468   1628992        Justin Jackson          2018             2          13
# 470   1628977        Hamidou Diallo          2018             2          15
# 473   1629004        Svi Mykhailiuk          2018             2          17
# 496   1629023       P.J. Washington          2019             1          12
# 516   1628981        Bruno Fernando          2019             2           4
# 518   1628998           Cody Martin          2019             2           6
# 534   1628986          Jaylen Hands          2019             2          26
# 545   1628962        Udoka Azubuike          2020             1          27
# 555   1629670          Jordan Nwora          2020             2          15
# 565   1629617          Reggie Perry          2020             2          27
# 646   1631204         Marcus Sasser          2023             1          25
# 651   1631124      Julian Strawther          2023             1          29
# 656   1631159        Leonard Miller          2023             2           3
# 674   1630592          Jalen Wilson          2023             2          21
# 680   1631218  Trayce Jackson-Davis          2023             2          27
#
#      overall_pick     team_id     team_city  team_name team_abbreviation  ...  \
# 456            25  1610612747   Los Angeles     Lakers               LAL  ...
# 468            43  1610612743        Denver    Nuggets               DEN  ...
# 470            45  1610612751      Brooklyn       Nets               BKN  ...
# 473            47  1610612747   Los Angeles     Lakers               LAL  ...
# 496            12  1610612766     Charlotte    Hornets               CHA  ...
# 516            34  1610612755  Philadelphia      76ers               PHI  ...
# 518            36  1610612766     Charlotte    Hornets               CHA  ...
# 534            56  1610612746            LA   Clippers               LAC  ...
# 545            27  1610612762          Utah       Jazz               UTA  ...
# 555            45  1610612749     Milwaukee      Bucks               MIL  ...
# 565            57  1610612746            LA   Clippers               LAC  ...
# 646            25  1610612763       Memphis  Grizzlies               MEM  ...
# 651            29  1610612754       Indiana     Pacers               IND  ...
# 656            33  1610612759   San Antonio      Spurs               SAS  ...
# 674            51  1610612751      Brooklyn       Nets               BKN  ...
# 680            57  1610612764    Washington    Wizards               WAS  ...
#
#     standing_reach standing_reach_ft_in body_fat_pct  hand_length hand_width  \
# 456          108.0               9' 0''         6.75         9.00      10.75
# 468          105.0               8' 9''         8.90         9.00       9.50
# 470          103.0               8' 7''         4.45         8.75       9.00
# 473          100.0               8' 4''         8.45         8.25       9.50
# 496          106.5            8' 10.5''         8.60         9.00      10.25
# 516          110.0               9' 2''         5.40         9.25      10.00
# 518          102.5             8' 6.5''         5.00         8.25       9.00
# 534           97.0               8' 1''         5.10         8.00       8.25
# 545          109.0             9'1.00''         9.61         9.25      10.00
# 555          104.0             8'8.00''        11.68         8.50       9.25
# 565          106.5            8'10.50''         8.40         9.25      11.00
# 646           99.5            8' 3.50''         0.00         8.75       9.50
# 651          105.0            8' 9.00''         0.00         8.25       8.25
# 656          106.5           8' 10.50''         0.00         9.50      10.50
# 674           99.5            8' 3.50''         0.00         8.25       9.00
# 680          106.0           8' 10.00''         0.00         9.25      10.75
#
#      standing_vertical_leap max_vertical_leap  lane_agility_time  \
# 456                    27.0              34.0              11.48
# 468                     0.0               0.0               0.00
# 470                    32.5              40.5              10.53
# 473                    30.5              37.0              11.25
# 496                     0.0               0.0               0.00
# 516                    29.5              33.5              11.29
# 518                    28.0              35.5              10.44
# 534                    33.0              41.5              10.73
# 545                    37.0              41.0              11.82
# 555                    29.0              35.0              11.29
# 565                    30.0              33.5              11.26
# 646                    27.0              35.0              10.68
# 651                    27.5              34.5              10.94
# 656                    32.0              37.5              11.00
# 674                    31.5              35.0              11.26
# 680                    33.0              36.5              11.80
#
#      modified_lane_agility_time three_quarter_sprint
# 456                        3.07                 3.18
# 468                        0.00                 0.00
# 470                        3.14                 3.10
# 473                        3.18                 3.15
# 496                        0.00                 0.00
# 516                        3.05                 3.21
# 518                        2.99                 3.32
# 534                        3.03                 3.12
# 545                        3.61                 3.23
# 555                        2.66                 3.43
# 565                        2.57                 3.25
# 646                        0.00                 3.43
# 651                        3.46                 3.31
# 656                        0.00                 3.33
# 674                        3.15                 3.20
# 680                        3.23                 3.20
#
# [16 rows x 30 columns]

# %%
draft_completo.drop_duplicates(subset=['draft_id'], inplace=True)

# %%
# Verificar duplicados basados en la columna 'player_id'
duplicados_player_id = draft_completo.duplicated(subset=['draft_id'])

# Mostrar las filas duplicadas basadas en 'player_id'
draft_completo[duplicados_player_id]
# Out:
# Empty DataFrame
# Columns: [draft_id, player_name, draft_season, round_number, round_pick, overall_pick, team_id, team_city, team_name, team_abbreviation, organization, organization_type, position, height_wo_shoes, height_wo_shoes_ft_in, height_w_shoes, height_w_shoes_ft_in, weight, wingspan, wingspan_ft_in, standing_reach, standing_reach_ft_in, body_fat_pct, hand_length, hand_width, standing_vertical_leap, max_vertical_leap, lane_agility_time, modified_lane_agility_time, three_quarter_sprint]
# Index: []
#
# [0 rows x 30 columns]

# %%
np.shape(draft_completo)
# Out:
# (666, 30)

# %% [markdown]
# ### Revision de valores nulos luego del merge

# %%
draft_completo.isnull().sum()
# Out:
# draft_id                      0
# player_name                   0
# draft_season                  0
# round_number                  0
# round_pick                    0
# overall_pick                  0
# team_id                       0
# team_city                     0
# team_name                     0
# team_abbreviation             0
# organization                  0
# organization_type             0
# position                      0
# height_wo_shoes               0
# height_wo_shoes_ft_in         0
# height_w_shoes                0
# height_w_shoes_ft_in          0
# weight                        0
# wingspan                      0
# wingspan_ft_in                0
# standing_reach                0
# standing_reach_ft_in          0
# body_fat_pct                  0
# hand_length                   0
# hand_width                    0
# standing_vertical_leap        0
# max_vertical_leap             0
# lane_agility_time             0
# modified_lane_agility_time    0
# three_quarter_sprint          0
# dtype: int64

# %% [markdown]
# ### Exportamos los datos

# %%
# Guardar el DataFrame en un archivo CSV
draft_completo.to_csv('draft_completo.csv', index=False)
