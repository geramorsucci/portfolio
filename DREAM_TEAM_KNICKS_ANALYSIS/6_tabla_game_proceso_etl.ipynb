# %% [markdown]
# # Proceso de ETL para la tabla de hechos de la base de datos NBA

# %%
#Carga de librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# Carga de los datos

# %%
#CARGA DEL DATASET
data = pd.read_csv("game.csv", sep=',')

# %% [markdown]
# Primer vistaso a las columnas

# %%
pd.options.display.max_columns = 60
pd.options.display.max_columns
# Out:
# 60

# %%
data.head(5)
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0
# 3  24600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0
# 4  24600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0
#
#    fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 0       NaN          NaN        NaN        NaN           NaN      16.0
# 1      59.0        0.339        NaN        NaN           NaN      16.0
# 2       NaN          NaN        NaN        NaN           NaN      17.0
# 3       NaN          NaN        NaN        NaN           NaN      21.0
# 4       NaN          NaN        NaN        NaN           NaN      13.0
#
#    fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  stl_home  \
# 0      29.0        0.552        NaN        NaN       NaN       NaN       NaN
# 1       NaN          NaN        NaN        NaN       NaN       NaN       NaN
# 2       NaN          NaN        NaN        NaN       NaN       NaN       NaN
# 3       NaN          NaN        NaN        NaN       NaN       NaN       NaN
# 4       NaN          NaN        NaN        NaN       NaN       NaN       NaN
#
#    blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 0       NaN       NaN      NaN      66.0               -2
# 1       NaN       NaN     21.0      56.0                5
# 2       NaN       NaN      NaN      59.0                6
# 3       NaN       NaN     20.0      63.0               16
# 4       NaN       NaN      NaN      33.0              -17
#
#    video_available_home  team_id_away team_abbreviation_away  \
# 0                     0    1610612752                    NYK
# 1                     0    1610610031                    PIT
# 2                     0    1610612738                    BOS
# 3                     0    1610612752                    NYK
# 4                     0    1610610036                    WAS
#
#         team_name_away matchup_away wl_away  fgm_away  fga_away  fg_pct_away  \
# 0      New York Knicks    NYK @ HUS       W      24.0       NaN          NaN
# 1   Pittsburgh Ironmen    PIT @ BOM       L      16.0      72.0        0.222
# 2       Boston Celtics    BOS @ PRO       L      21.0       NaN          NaN
# 3      New York Knicks    NYK @ CHS       L      16.0       NaN          NaN
# 4  Washington Capitols    WAS @ DEF       W      18.0       NaN          NaN
#
#    fg3m_away  fg3a_away  fg3_pct_away  ftm_away  fta_away  ft_pct_away  \
# 0        NaN        NaN           NaN      20.0      26.0        0.769
# 1        NaN        NaN           NaN      19.0       NaN          NaN
# 2        NaN        NaN           NaN      11.0       NaN          NaN
# 3        NaN        NaN           NaN      15.0       NaN          NaN
# 4        NaN        NaN           NaN      14.0       NaN          NaN
#
#    oreb_away  dreb_away  reb_away  ast_away  stl_away  blk_away  tov_away  \
# 0        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN        NaN       NaN       NaN       NaN       NaN       NaN
#
#    pf_away  pts_away  plus_minus_away  video_available_away     season_type
# 0      NaN      68.0                2                     0  Regular Season
# 1     25.0      51.0               -5                     0  Regular Season
# 2      NaN      53.0               -6                     0  Regular Season
# 3     22.0      47.0              -16                     0  Regular Season
# 4      NaN      50.0               17                     0  Regular Season

# %% [markdown]
# Se comprueba que el dataset cargado tiene la cantidad de registros y columnas especificadas

# %%
np.shape(data)
# Out:
# (65698, 55)

# %% [markdown]
# Se procedera a establecer un filtrado por fechas. Esto es para utilizar las temporadas siguientes (2020/2021) (2021/2022) (2022/2023) como fijan los parámetros del proyecto.

# %% [markdown]
# Dado que el final de la temporada anterior se retrasó debido la pandemia COVID-19, la NBA aprobó una fecha excepcional de inicio para el 22 de diciembre de 2020, cuando lo habitual era comenzar en el mes de octubre.

# %%
# Filtra los datos en fechas mayores a 2021-01-01.
data = data[data["game_date"]>'2020-12-31']
data = data[data["game_date"]<'2023-6-13']
np.shape(data)
# Out:
# (3877, 55)

# %%
data.tail(5)
# Out:
#        season_id  team_id_home team_abbreviation_home  team_name_home  \
# 65693      42022    1610612748                    MIA      Miami Heat
# 65694      42022    1610612748                    MIA      Miami Heat
# 65695      42022    1610612743                    DEN  Denver Nuggets
# 65696      32022    1610616834                    LBN     Team LeBron
# 65697      32022    1610616834                    LBN     Team LeBron
#
#         game_id            game_date matchup_home wl_home  min  fgm_home  \
# 65693  42200403  2023-06-07 00:00:00  MIA vs. DEN       L  240      34.0
# 65694  42200404  2023-06-09 00:00:00  MIA vs. DEN       L  240      35.0
# 65695  42200405  2023-06-12 00:00:00  DEN vs. MIA       W  240      38.0
# 65696  32200001  2023-02-19 00:00:00  LBN vs. GNS       L  221      79.0
# 65697  32200001  2023-02-19 00:00:00  LBN vs. GNS       L  221      79.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 65693      92.0        0.370       11.0       35.0         0.314      15.0
# 65694      78.0        0.449        8.0       25.0         0.320      17.0
# 65695      84.0        0.452        5.0       28.0         0.179      13.0
# 65696     132.0        0.598       17.0       60.0         0.283       0.0
# 65697     132.0        0.598       17.0       60.0         0.283       0.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 65693      19.0        0.789       10.0       23.0      33.0      20.0
# 65694      20.0        0.850        8.0       29.0      37.0      23.0
# 65695      23.0        0.565       11.0       46.0      57.0      21.0
# 65696       0.0          NaN       13.0       32.0      45.0      49.0
# 65697       0.0          NaN       13.0       32.0      45.0      49.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 65693       7.0       3.0       4.0     22.0      94.0              -15
# 65694       2.0       3.0      15.0     19.0      95.0              -13
# 65695       6.0       7.0      15.0     13.0      94.0                5
# 65696       7.0       2.0      10.0      5.0     175.0               -9
# 65697       7.0       2.0      10.0      5.0     175.0               -9
#
#        video_available_home  team_id_away team_abbreviation_away  \
# 65693                     1    1610612743                    DEN
# 65694                     1    1610612743                    DEN
# 65695                     1    1610612748                    MIA
# 65696                     1    1610616833                    GNS
# 65697                     1    1610616833                    GNS
#
#        team_name_away matchup_away wl_away  fgm_away  fga_away  fg_pct_away  \
# 65693  Denver Nuggets    DEN @ MIA       W      41.0      80.0        0.513
# 65694  Denver Nuggets    DEN @ MIA       W      39.0      79.0        0.494
# 65695      Miami Heat    MIA @ DEN       L      33.0      96.0        0.344
# 65696    Team Giannis    GNS @ LBN       W      76.0     123.0        0.618
# 65697    Team Giannis    GNS @ LBN       W      76.0     123.0        0.618
#
#        fg3m_away  fg3a_away  fg3_pct_away  ftm_away  fta_away  ft_pct_away  \
# 65693        5.0       18.0         0.278      22.0      27.0        0.815
# 65694       14.0       28.0         0.500      16.0      21.0        0.762
# 65695        9.0       35.0         0.257      14.0      16.0        0.875
# 65696       29.0       66.0         0.439       3.0       4.0        0.750
# 65697       29.0       66.0         0.439       3.0       4.0        0.750
#
#        oreb_away  dreb_away  reb_away  ast_away  stl_away  blk_away  tov_away  \
# 65693       13.0       45.0      58.0      28.0       3.0       5.0      14.0
# 65694        5.0       29.0      34.0      26.0      11.0       7.0       8.0
# 65695       11.0       33.0      44.0      18.0       9.0       7.0       8.0
# 65696       10.0       36.0      46.0      43.0       8.0       1.0      12.0
# 65697       10.0       36.0      46.0      43.0       8.0       1.0      12.0
#
#        pf_away  pts_away  plus_minus_away  video_available_away season_type
# 65693     18.0     109.0               15                     1    Playoffs
# 65694     18.0     108.0               13                     1    Playoffs
# 65695     21.0      89.0               -5                     1    Playoffs
# 65696      2.0     184.0                9                     1    All-Star
# 65697      2.0     184.0                9                     1    All Star

# %% [markdown]
# ### Se consultan valores nulos por primera vez.

# %%
# PORCENTAJE DE VALORES NULOS
nulos_total = data.isnull().sum()
porcentaje_nulos = (nulos_total / len(data)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': nulos_total,
    'Porcentaje Nulos': porcentaje_nulos
})

print(resumen_nulos)
# Out:
#                         Valores Nulos  Porcentaje Nulos
# season_id                           0          0.000000
# team_id_home                        0          0.000000
# team_abbreviation_home              0          0.000000
# team_name_home                      0          0.000000
# game_id                             0          0.000000
# game_date                           0          0.000000
# matchup_home                        0          0.000000
# wl_home                             0          0.000000
# min                                 0          0.000000
# fgm_home                            0          0.000000
# fga_home                            0          0.000000
# fg_pct_home                         0          0.000000
# fg3m_home                           0          0.000000
# fg3a_home                           0          0.000000
# fg3_pct_home                        0          0.000000
# ftm_home                            0          0.000000
# fta_home                            0          0.000000
# ft_pct_home                         2          0.051586
# oreb_home                           0          0.000000
# dreb_home                           0          0.000000
# reb_home                            0          0.000000
# ast_home                            0          0.000000
# stl_home                            0          0.000000
# blk_home                            0          0.000000
# tov_home                            0          0.000000
# pf_home                             0          0.000000
# pts_home                            0          0.000000
# plus_minus_home                     0          0.000000
# video_available_home                0          0.000000
# team_id_away                        0          0.000000
# team_abbreviation_away              0          0.000000
# team_name_away                      0          0.000000
# matchup_away                        0          0.000000
# wl_away                             0          0.000000
# fgm_away                            0          0.000000
# fga_away                            0          0.000000
# fg_pct_away                         0          0.000000
# fg3m_away                           0          0.000000
# fg3a_away                           0          0.000000
# fg3_pct_away                        0          0.000000
# ftm_away                            0          0.000000
# fta_away                            0          0.000000
# ft_pct_away                         0          0.000000
# oreb_away                           0          0.000000
# dreb_away                           0          0.000000
# reb_away                            0          0.000000
# ast_away                            0          0.000000
# stl_away                            0          0.000000
# blk_away                            0          0.000000
# tov_away                            0          0.000000
# pf_away                             0          0.000000
# pts_away                            0          0.000000
# plus_minus_away                     0          0.000000
# video_available_away                0          0.000000
# season_type                         0          0.000000

# %% [markdown]
# Observamos que la integridad de nuestros datos es súper sólida debido a que tenemos 2 datos faltantes unicamente, los cuales estan alojados en la columna ft_pct_home.

# %% [markdown]
# Imprimimos esos datos para tratarlos de forma particular según su situación.

# %%
valores_faltantes = data[data['ft_pct_home'].isnull()]
print(valores_faltantes)
# Out:
#        season_id  team_id_home team_abbreviation_home team_name_home  \
# 65696      32022    1610616834                    LBN    Team LeBron
# 65697      32022    1610616834                    LBN    Team LeBron
#
#         game_id            game_date matchup_home wl_home  min  fgm_home  \
# 65696  32200001  2023-02-19 00:00:00  LBN vs. GNS       L  221      79.0
# 65697  32200001  2023-02-19 00:00:00  LBN vs. GNS       L  221      79.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 65696     132.0        0.598       17.0       60.0         0.283       0.0
# 65697     132.0        0.598       17.0       60.0         0.283       0.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 65696       0.0          NaN       13.0       32.0      45.0      49.0
# 65697       0.0          NaN       13.0       32.0      45.0      49.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 65696       7.0       2.0      10.0      5.0     175.0               -9
# 65697       7.0       2.0      10.0      5.0     175.0               -9
#
#        video_available_home  team_id_away team_abbreviation_away  \
# 65696                     1    1610616833                    GNS
# 65697                     1    1610616833                    GNS
#
#       team_name_away matchup_away wl_away  fgm_away  fga_away  fg_pct_away  \
# 65696   Team Giannis    GNS @ LBN       W      76.0     123.0        0.618
# 65697   Team Giannis    GNS @ LBN       W      76.0     123.0        0.618
#
#        fg3m_away  fg3a_away  fg3_pct_away  ftm_away  fta_away  ft_pct_away  \
# 65696       29.0       66.0         0.439       3.0       4.0         0.75
# 65697       29.0       66.0         0.439       3.0       4.0         0.75
#
#        oreb_away  dreb_away  reb_away  ast_away  stl_away  blk_away  tov_away  \
# 65696       10.0       36.0      46.0      43.0       8.0       1.0      12.0
# 65697       10.0       36.0      46.0      43.0       8.0       1.0      12.0
#
#        pf_away  pts_away  plus_minus_away  video_available_away season_type
# 65696      2.0     184.0                9                     1    All-Star
# 65697      2.0     184.0                9                     1    All Star

# %% [markdown]
# El 19 de febrero de 2023, durante el NBA All-Star Game 2023, el equipo dirigido por LeBron James (Team LeBron) jugó contra el equipo dirigido por Giannis Antetokounmpo (Team Giannis). En ese juego, la estadística de porcentaje de tiros libres (FT%) para el Team LeBron fue del 87.5%. Rellenaremos el dato faltante con el dato real. Este dato fue sacado de la página oficial de la NBA (nba.com)

# %% [markdown]
# Antes de rellenar el dato podemos observar que la fila completa está repetida, por ende procedemos a eliminar una.

# %%
data = data.drop(65697)

# %% [markdown]
# Ahora si rellenamos el dato faltante de la columna 'ft_pct_home' con su valor real.

# %%
data.loc[65696, 'ft_pct_home'] = 0.875

# %%
valor_f1 = data.loc[65696]
print(valor_f1)
# Out:
# season_id                               32022
# team_id_home                       1610616834
# team_abbreviation_home                    LBN
# team_name_home                    Team LeBron
# game_id                              32200001
# game_date                 2023-02-19 00:00:00
# matchup_home                      LBN vs. GNS
# wl_home                                     L
# min                                       221
# fgm_home                                 79.0
# fga_home                                132.0
# fg_pct_home                             0.598
# fg3m_home                                17.0
# fg3a_home                                60.0
# fg3_pct_home                            0.283
# ftm_home                                  0.0
# fta_home                                  0.0
# ft_pct_home                             0.875
# oreb_home                                13.0
# dreb_home                                32.0
# reb_home                                 45.0
# ast_home                                 49.0
# stl_home                                  7.0
# blk_home                                  2.0
# tov_home                                 10.0
# pf_home                                   5.0
# pts_home                                175.0
# plus_minus_home                            -9
# video_available_home                        1
# team_id_away                       1610616833
# team_abbreviation_away                    GNS
# team_name_away                   Team Giannis
# matchup_away                        GNS @ LBN
# wl_away                                     W
# fgm_away                                 76.0
# fga_away                                123.0
# fg_pct_away                             0.618
# fg3m_away                                29.0
# fg3a_away                                66.0
# fg3_pct_away                            0.439
# ftm_away                                  3.0
# fta_away                                  4.0
# ft_pct_away                              0.75
# oreb_away                                10.0
# dreb_away                                36.0
# reb_away                                 46.0
# ast_away                                 43.0
# stl_away                                  8.0
# blk_away                                  1.0
# tov_away                                 12.0
# pf_away                                   2.0
# pts_away                                184.0
# plus_minus_away                             9
# video_available_away                        1
# season_type                          All-Star
# Name: 65696, dtype: object

# %% [markdown]
# Controlamos que no existan más datos duplicados.

# %%
duplicados = data.duplicated(keep=False)

# Filtra las filas duplicadas
datos_duplicados = data[duplicados]
print(datos_duplicados)
# Out:
# Empty DataFrame
# Columns: [season_id, team_id_home, team_abbreviation_home, team_name_home, game_id, game_date, matchup_home, wl_home, min, fgm_home, fga_home, fg_pct_home, fg3m_home, fg3a_home, fg3_pct_home, ftm_home, fta_home, ft_pct_home, oreb_home, dreb_home, reb_home, ast_home, stl_home, blk_home, tov_home, pf_home, pts_home, plus_minus_home, video_available_home, team_id_away, team_abbreviation_away, team_name_away, matchup_away, wl_away, fgm_away, fga_away, fg_pct_away, fg3m_away, fg3a_away, fg3_pct_away, ftm_away, fta_away, ft_pct_away, oreb_away, dreb_away, reb_away, ast_away, stl_away, blk_away, tov_away, pf_away, pts_away, plus_minus_away, video_available_away, season_type]
# Index: []

# %% [markdown]
# Controlamos nuevamente que no tengamos valores faltantes.

# %%
# PORCENTAJE DE VALORES NULOS
nulos_total = data.isnull().sum()
porcentaje_nulos = (nulos_total / len(data)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': nulos_total,
    'Porcentaje Nulos': porcentaje_nulos
})

print(resumen_nulos)
# Out:
#                         Valores Nulos  Porcentaje Nulos
# season_id                           0               0.0
# team_id_home                        0               0.0
# team_abbreviation_home              0               0.0
# team_name_home                      0               0.0
# game_id                             0               0.0
# game_date                           0               0.0
# matchup_home                        0               0.0
# wl_home                             0               0.0
# min                                 0               0.0
# fgm_home                            0               0.0
# fga_home                            0               0.0
# fg_pct_home                         0               0.0
# fg3m_home                           0               0.0
# fg3a_home                           0               0.0
# fg3_pct_home                        0               0.0
# ftm_home                            0               0.0
# fta_home                            0               0.0
# ft_pct_home                         0               0.0
# oreb_home                           0               0.0
# dreb_home                           0               0.0
# reb_home                            0               0.0
# ast_home                            0               0.0
# stl_home                            0               0.0
# blk_home                            0               0.0
# tov_home                            0               0.0
# pf_home                             0               0.0
# pts_home                            0               0.0
# plus_minus_home                     0               0.0
# video_available_home                0               0.0
# team_id_away                        0               0.0
# team_abbreviation_away              0               0.0
# team_name_away                      0               0.0
# matchup_away                        0               0.0
# wl_away                             0               0.0
# fgm_away                            0               0.0
# fga_away                            0               0.0
# fg_pct_away                         0               0.0
# fg3m_away                           0               0.0
# fg3a_away                           0               0.0
# fg3_pct_away                        0               0.0
# ftm_away                            0               0.0
# fta_away                            0               0.0
# ft_pct_away                         0               0.0
# oreb_away                           0               0.0
# dreb_away                           0               0.0
# reb_away                            0               0.0
# ast_away                            0               0.0
# stl_away                            0               0.0
# blk_away                            0               0.0
# tov_away                            0               0.0
# pf_away                             0               0.0
# pts_away                            0               0.0
# plus_minus_away                     0               0.0
# video_available_away                0               0.0
# season_type                         0               0.0

# %% [markdown]
# Ahora que sabemos que el dataset esta correctamente filtrado y sin valores faltantes procedemos a revisar el formato de nuestras columnas antes de exportar el dataset con el ETL finalizado.

# %%
print(data.dtypes)
# Out:
# season_id                   int64
# team_id_home                int64
# team_abbreviation_home     object
# team_name_home             object
# game_id                     int64
# game_date                  object
# matchup_home               object
# wl_home                    object
# min                         int64
# fgm_home                  float64
# fga_home                  float64
# fg_pct_home               float64
# fg3m_home                 float64
# fg3a_home                 float64
# fg3_pct_home              float64
# ftm_home                  float64
# fta_home                  float64
# ft_pct_home               float64
# oreb_home                 float64
# dreb_home                 float64
# reb_home                  float64
# ast_home                  float64
# stl_home                  float64
# blk_home                  float64
# tov_home                  float64
# pf_home                   float64
# pts_home                  float64
# plus_minus_home             int64
# video_available_home        int64
# team_id_away                int64
# team_abbreviation_away     object
# team_name_away             object
# matchup_away               object
# wl_away                    object
# fgm_away                  float64
# fga_away                  float64
# fg_pct_away               float64
# fg3m_away                 float64
# fg3a_away                 float64
# fg3_pct_away              float64
# ftm_away                  float64
# fta_away                  float64
# ft_pct_away               float64
# oreb_away                 float64
# dreb_away                 float64
# reb_away                  float64
# ast_away                  float64
# stl_away                  float64
# blk_away                  float64
# tov_away                  float64
# pf_away                   float64
# pts_away                  float64
# plus_minus_away             int64
# video_available_away        int64
# season_type                object
# dtype: object

# %% [markdown]
# Observamos que la columna de fechas esta en formato 'object'.

# %% [markdown]
# La cambiamos a formato 'datetime'.

# %%
data['game_date'] = pd.to_datetime(data['game_date'], errors='coerce')

# %% [markdown]
# Revisamos nuevamente el formato para corroborar los cambios.

# %%
print(data['game_date'].dtypes)
# Out:
# datetime64[ns]

# %%
data.head(5)
# Out:
#        season_id  team_id_home team_abbreviation_home         team_name_home  \
# 61772      22020    1610612764                    WAS     Washington Wizards
# 61773      22020    1610612762                    UTA              Utah Jazz
# 61774      22020    1610612745                    HOU        Houston Rockets
# 61775      22020    1610612753                    ORL          Orlando Magic
# 61776      22020    1610612760                    OKC  Oklahoma City Thunder
#
#         game_id  game_date matchup_home wl_home  min  fgm_home  fga_home  \
# 61772  22000063 2020-12-31  WAS vs. CHI       L  240      42.0      84.0
# 61773  22000068 2020-12-31  UTA vs. PHX       L  240      35.0      84.0
# 61774  22000065 2020-12-31  HOU vs. SAC       W  240      45.0      86.0
# 61775  22000064 2020-12-31  ORL vs. PHI       L  240      33.0      95.0
# 61776  22000067 2020-12-31  OKC vs. NOP       L  240      30.0      80.0
#
#        fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  fta_home  \
# 61772        0.500       14.0       29.0         0.483      32.0      41.0
# 61773        0.417       12.0       34.0         0.353      13.0      19.0
# 61774        0.523       13.0       36.0         0.361      19.0      25.0
# 61775        0.347        7.0       28.0         0.250      19.0      21.0
# 61776        0.375       15.0       48.0         0.313       5.0      15.0
#
#        ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  stl_home  \
# 61772        0.780        9.0       28.0      37.0      27.0       8.0
# 61773        0.684       10.0       36.0      46.0      16.0       8.0
# 61774        0.760       10.0       35.0      45.0      26.0      10.0
# 61775        0.905       10.0       38.0      48.0      17.0       2.0
# 61776        0.333        7.0       33.0      40.0      24.0       6.0
#
#        blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 61772       4.0      14.0     27.0     130.0               -3
# 61773       3.0      14.0     15.0      95.0              -11
# 61774       6.0      18.0     14.0     122.0                3
# 61775       5.0      11.0     15.0      92.0              -24
# 61776       3.0      19.0     20.0      80.0              -33
#
#        video_available_home  team_id_away team_abbreviation_away  \
# 61772                     1    1610612741                    CHI
# 61773                     1    1610612756                    PHX
# 61774                     1    1610612758                    SAC
# 61775                     1    1610612755                    PHI
# 61776                     1    1610612740                    NOP
#
#              team_name_away matchup_away wl_away  fgm_away  fga_away  \
# 61772         Chicago Bulls    CHI @ WAS       W      50.0      92.0
# 61773          Phoenix Suns    PHX @ UTA       W      41.0      84.0
# 61774      Sacramento Kings    SAC @ HOU       L      45.0      96.0
# 61775    Philadelphia 76ers    PHI @ ORL       W      44.0      91.0
# 61776  New Orleans Pelicans    NOP @ OKC       W      44.0      91.0
#
#        fg_pct_away  fg3m_away  fg3a_away  fg3_pct_away  ftm_away  fta_away  \
# 61772        0.543       14.0       36.0         0.389      19.0      25.0
# 61773        0.488       17.0       33.0         0.515       7.0      10.0
# 61774        0.469       11.0       33.0         0.333      18.0      24.0
# 61775        0.484       15.0       33.0         0.455      13.0      15.0
# 61776        0.484       13.0       36.0         0.361      12.0      19.0
#
#        ft_pct_away  oreb_away  dreb_away  reb_away  ast_away  stl_away  \
# 61772        0.760        9.0       35.0      44.0      34.0       9.0
# 61773        0.700        5.0       36.0      41.0      26.0       5.0
# 61774        0.750       14.0       31.0      45.0      23.0      11.0
# 61775        0.867        7.0       47.0      54.0      23.0       7.0
# 61776        0.632       14.0       44.0      58.0      23.0       9.0
#
#        blk_away  tov_away  pf_away  pts_away  plus_minus_away  \
# 61772       3.0      17.0     27.0     133.0                3
# 61773       6.0      15.0     17.0     106.0               11
# 61774       5.0      15.0     21.0     119.0               -3
# 61775      10.0      15.0     23.0     116.0               24
# 61776       4.0      13.0     16.0     113.0               33
#
#        video_available_away     season_type
# 61772                     1  Regular Season
# 61773                     1  Regular Season
# 61774                     1  Regular Season
# 61775                     1  Regular Season
# 61776                     1  Regular Season

# %% [markdown]
# Le cambiamos el nombre a la columna, ya que min es un caracter reservado de SQL.

# %%
data = data.rename(columns={'min': 'game_minutes'})

# %%
lista_a_dropear = ['video_available_away','video_available_home']

# %% [markdown]
# Eliminamos columnas que no ofrecen datos al análisis.

# %%
data.drop(lista_a_dropear, axis=1, inplace=True)

# %%
np.shape(data)
# Out:
# (3876, 53)

# %% [markdown]
# Estandarizamos las ids de las temporadas según la tabla de dimensión season.

# %%
unique_values = data['season_id'].unique()
unique_values
# Out:
# array([22020, 42020, 32020, 22021, 12021, 42021, 32021, 22022, 12022,
#        42022, 32022])

# %%
replacement_dict = {
    22020: 2021, 42020: 2021, 32020: 2021,
    22021: 2022, 12021: 2022, 42021: 2022, 32021: 2022,
    22022: 2023, 12022: 2023, 42022: 2023, 32022: 2023
}


data['season_id'] = data['season_id'].replace(replacement_dict)

# %%
unique_values = data['season_id'].unique()
unique_values
# Out:
# array([2021, 2022, 2023])

# %%
data
# Out:
#        season_id  team_id_home team_abbreviation_home         team_name_home  \
# 61772       2021    1610612764                    WAS     Washington Wizards
# 61773       2021    1610612762                    UTA              Utah Jazz
# 61774       2021    1610612745                    HOU        Houston Rockets
# 61775       2021    1610612753                    ORL          Orlando Magic
# 61776       2021    1610612760                    OKC  Oklahoma City Thunder
# ...          ...           ...                    ...                    ...
# 65692       2023    1610612743                    DEN         Denver Nuggets
# 65693       2023    1610612748                    MIA             Miami Heat
# 65694       2023    1610612748                    MIA             Miami Heat
# 65695       2023    1610612743                    DEN         Denver Nuggets
# 65696       2023    1610616834                    LBN            Team LeBron
#
#         game_id  game_date matchup_home wl_home  game_minutes  fgm_home  \
# 61772  22000063 2020-12-31  WAS vs. CHI       L           240      42.0
# 61773  22000068 2020-12-31  UTA vs. PHX       L           240      35.0
# 61774  22000065 2020-12-31  HOU vs. SAC       W           240      45.0
# 61775  22000064 2020-12-31  ORL vs. PHI       L           240      33.0
# 61776  22000067 2020-12-31  OKC vs. NOP       L           240      30.0
# ...         ...        ...          ...     ...           ...       ...
# 65692  42200402 2023-06-04  DEN vs. MIA       L           240      39.0
# 65693  42200403 2023-06-07  MIA vs. DEN       L           240      34.0
# 65694  42200404 2023-06-09  MIA vs. DEN       L           240      35.0
# 65695  42200405 2023-06-12  DEN vs. MIA       W           240      38.0
# 65696  32200001 2023-02-19  LBN vs. GNS       L           221      79.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 61772      84.0        0.500       14.0       29.0         0.483      32.0
# 61773      84.0        0.417       12.0       34.0         0.353      13.0
# 61774      86.0        0.523       13.0       36.0         0.361      19.0
# 61775      95.0        0.347        7.0       28.0         0.250      19.0
# 61776      80.0        0.375       15.0       48.0         0.313       5.0
# ...         ...          ...        ...        ...           ...       ...
# 65692      75.0        0.520       11.0       28.0         0.393      19.0
# 65693      92.0        0.370       11.0       35.0         0.314      15.0
# 65694      78.0        0.449        8.0       25.0         0.320      17.0
# 65695      84.0        0.452        5.0       28.0         0.179      13.0
# 65696     132.0        0.598       17.0       60.0         0.283       0.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 61772      41.0        0.780        9.0       28.0      37.0      27.0
# 61773      19.0        0.684       10.0       36.0      46.0      16.0
# 61774      25.0        0.760       10.0       35.0      45.0      26.0
# 61775      21.0        0.905       10.0       38.0      48.0      17.0
# 61776      15.0        0.333        7.0       33.0      40.0      24.0
# ...         ...          ...        ...        ...       ...       ...
# 65692      22.0        0.864        9.0       29.0      38.0      23.0
# 65693      19.0        0.789       10.0       23.0      33.0      20.0
# 65694      20.0        0.850        8.0       29.0      37.0      23.0
# 65695      23.0        0.565       11.0       46.0      57.0      21.0
# 65696       0.0        0.875       13.0       32.0      45.0      49.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 61772       8.0       4.0      14.0     27.0     130.0               -3
# 61773       8.0       3.0      14.0     15.0      95.0              -11
# 61774      10.0       6.0      18.0     14.0     122.0                3
# 61775       2.0       5.0      11.0     15.0      92.0              -24
# 61776       6.0       3.0      19.0     20.0      80.0              -33
# ...         ...       ...       ...      ...       ...              ...
# 65692       7.0       2.0      14.0     21.0     108.0               -3
# 65693       7.0       3.0       4.0     22.0      94.0              -15
# 65694       2.0       3.0      15.0     19.0      95.0              -13
# 65695       6.0       7.0      15.0     13.0      94.0                5
# 65696       7.0       2.0      10.0      5.0     175.0               -9
#
#        team_id_away team_abbreviation_away        team_name_away matchup_away  \
# 61772    1610612741                    CHI         Chicago Bulls    CHI @ WAS
# 61773    1610612756                    PHX          Phoenix Suns    PHX @ UTA
# 61774    1610612758                    SAC      Sacramento Kings    SAC @ HOU
# 61775    1610612755                    PHI    Philadelphia 76ers    PHI @ ORL
# 61776    1610612740                    NOP  New Orleans Pelicans    NOP @ OKC
# ...             ...                    ...                   ...          ...
# 65692    1610612748                    MIA            Miami Heat    MIA @ DEN
# 65693    1610612743                    DEN        Denver Nuggets    DEN @ MIA
# 65694    1610612743                    DEN        Denver Nuggets    DEN @ MIA
# 65695    1610612748                    MIA            Miami Heat    MIA @ DEN
# 65696    1610616833                    GNS          Team Giannis    GNS @ LBN
#
#       wl_away  fgm_away  fga_away  fg_pct_away  fg3m_away  fg3a_away  \
# 61772       W      50.0      92.0        0.543       14.0       36.0
# 61773       W      41.0      84.0        0.488       17.0       33.0
# 61774       L      45.0      96.0        0.469       11.0       33.0
# 61775       W      44.0      91.0        0.484       15.0       33.0
# 61776       W      44.0      91.0        0.484       13.0       36.0
# ...       ...       ...       ...          ...        ...        ...
# 65692       W      38.0      78.0        0.487       17.0       35.0
# 65693       W      41.0      80.0        0.513        5.0       18.0
# 65694       W      39.0      79.0        0.494       14.0       28.0
# 65695       L      33.0      96.0        0.344        9.0       35.0
# 65696       W      76.0     123.0        0.618       29.0       66.0
#
#        fg3_pct_away  ftm_away  fta_away  ft_pct_away  oreb_away  dreb_away  \
# 61772         0.389      19.0      25.0        0.760        9.0       35.0
# 61773         0.515       7.0      10.0        0.700        5.0       36.0
# 61774         0.333      18.0      24.0        0.750       14.0       31.0
# 61775         0.455      13.0      15.0        0.867        7.0       47.0
# 61776         0.361      12.0      19.0        0.632       14.0       44.0
# ...             ...       ...       ...          ...        ...        ...
# 65692         0.486      18.0      20.0        0.900        8.0       23.0
# 65693         0.278      22.0      27.0        0.815       13.0       45.0
# 65694         0.500      16.0      21.0        0.762        5.0       29.0
# 65695         0.257      14.0      16.0        0.875       11.0       33.0
# 65696         0.439       3.0       4.0        0.750       10.0       36.0
#
#        reb_away  ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  \
# 61772      44.0      34.0       9.0       3.0      17.0     27.0     133.0
# 61773      41.0      26.0       5.0       6.0      15.0     17.0     106.0
# 61774      45.0      23.0      11.0       5.0      15.0     21.0     119.0
# 61775      54.0      23.0       7.0      10.0      15.0     23.0     116.0
# 61776      58.0      23.0       9.0       4.0      13.0     16.0     113.0
# ...         ...       ...       ...       ...       ...      ...       ...
# 65692      31.0      28.0       5.0       4.0      11.0     22.0     111.0
# 65693      58.0      28.0       3.0       5.0      14.0     18.0     109.0
# 65694      34.0      26.0      11.0       7.0       8.0     18.0     108.0
# 65695      44.0      18.0       9.0       7.0       8.0     21.0      89.0
# 65696      46.0      43.0       8.0       1.0      12.0      2.0     184.0
#
#        plus_minus_away     season_type
# 61772                3  Regular Season
# 61773               11  Regular Season
# 61774               -3  Regular Season
# 61775               24  Regular Season
# 61776               33  Regular Season
# ...                ...             ...
# 65692                3        Playoffs
# 65693               15        Playoffs
# 65694               13        Playoffs
# 65695               -5        Playoffs
# 65696                9        All-Star
#
# [3876 rows x 53 columns]

# %%
data.dtypes
# Out:
# season_id                          int64
# team_id_home                       int64
# team_abbreviation_home            object
# team_name_home                    object
# game_id                            int64
# game_date                 datetime64[ns]
# matchup_home                      object
# wl_home                           object
# game_minutes                       int64
# fgm_home                         float64
# fga_home                         float64
# fg_pct_home                      float64
# fg3m_home                        float64
# fg3a_home                        float64
# fg3_pct_home                     float64
# ftm_home                         float64
# fta_home                         float64
# ft_pct_home                      float64
# oreb_home                        float64
# dreb_home                        float64
# reb_home                         float64
# ast_home                         float64
# stl_home                         float64
# blk_home                         float64
# tov_home                         float64
# pf_home                          float64
# pts_home                         float64
# plus_minus_home                    int64
# team_id_away                       int64
# team_abbreviation_away            object
# team_name_away                    object
# matchup_away                      object
# wl_away                           object
# fgm_away                         float64
# fga_away                         float64
# fg_pct_away                      float64
# fg3m_away                        float64
# fg3a_away                        float64
# fg3_pct_away                     float64
# ftm_away                         float64
# fta_away                         float64
# ft_pct_away                      float64
# oreb_away                        float64
# dreb_away                        float64
# reb_away                         float64
# ast_away                         float64
# stl_away                         float64
# blk_away                         float64
# tov_away                         float64
# pf_away                          float64
# pts_away                         float64
# plus_minus_away                    int64
# season_type                       object
# dtype: object

# %% [markdown]
# Verificamos datos duplicados.

# %%
duplicate_indices = data[data.duplicated(subset=['season_id', 'game_id', 'team_id_home', 'team_id_away'], keep=False)].index.tolist()

data.loc[duplicate_indices]
# Out:
#        season_id  team_id_home team_abbreviation_home team_name_home  \
# 62926       2021    1610616833                    DRT    Team Durant
# 62927       2021    1610616833                    DRT    Team Durant
#
#         game_id  game_date matchup_home wl_home  game_minutes  fgm_home  \
# 62926  32000001 2021-03-07  DRT vs. LBN       L           240      60.0
# 62927  32000001 2021-03-07  DRT vs. LBN       L           240      60.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 62926     114.0        0.526       27.0       72.0         0.375       3.0
# 62927     114.0        0.526       27.0       72.0         0.375       3.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 62926       5.0          0.6       10.0       31.0      41.0      47.0
# 62927       5.0          0.6       10.0       31.0      41.0      47.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 62926      15.0       0.0      14.0      8.0     150.0              -20
# 62927      15.0       0.0      14.0      8.0     150.0              -20
#
#        team_id_away team_abbreviation_away team_name_away matchup_away  \
# 62926    1610616834                    LBN    Team LeBron    LBN @ DRT
# 62927    1610616834                    LBN    Team LeBron    LBN @ DRT
#
#       wl_away  fgm_away  fga_away  fg_pct_away  fg3m_away  fg3a_away  \
# 62926       W      68.0     107.0        0.636       31.0       61.0
# 62927       W      68.0     107.0        0.636       31.0       61.0
#
#        fg3_pct_away  ftm_away  fta_away  ft_pct_away  oreb_away  dreb_away  \
# 62926         0.508       3.0       5.0          0.6        8.0       40.0
# 62927         0.508       3.0       5.0          0.6        8.0       40.0
#
#        reb_away  ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  \
# 62926      48.0      46.0       9.0       3.0      18.0      8.0     170.0
# 62927      48.0      46.0       9.0       3.0      18.0      8.0     170.0
#
#        plus_minus_away season_type
# 62926               20    All-Star
# 62927               20    All Star

# %%
# Eliminar los duplicados en el mismo DataFrame
data.drop_duplicates(subset=['season_id', 'game_id', 'team_id_home', 'team_id_away'], keep='first', inplace=True)

# %%
duplicate_indices = data[data.duplicated(subset=['season_id', 'game_id', 'team_id_home', 'team_id_away'], keep=False)].index.tolist()

data.loc[duplicate_indices]
# Out:
# Empty DataFrame
# Columns: [season_id, team_id_home, team_abbreviation_home, team_name_home, game_id, game_date, matchup_home, wl_home, game_minutes, fgm_home, fga_home, fg_pct_home, fg3m_home, fg3a_home, fg3_pct_home, ftm_home, fta_home, ft_pct_home, oreb_home, dreb_home, reb_home, ast_home, stl_home, blk_home, tov_home, pf_home, pts_home, plus_minus_home, team_id_away, team_abbreviation_away, team_name_away, matchup_away, wl_away, fgm_away, fga_away, fg_pct_away, fg3m_away, fg3a_away, fg3_pct_away, ftm_away, fta_away, ft_pct_away, oreb_away, dreb_away, reb_away, ast_away, stl_away, blk_away, tov_away, pf_away, pts_away, plus_minus_away, season_type]
# Index: []

# %%
np.shape(data)
# Out:
# (3875, 53)

# %% [markdown]
# ## Ahora verificaremos la integridad de la tabla de dimensión game_info

# %%
#CARGA DEL DATASET
dim = pd.read_csv("game_info_filtrado.csv", sep=',')

# %%
# Encontrar las game_id que están en df_fact pero no en df_dim
missing_in_dim = set(data['game_id']) - set(dim['game_id'])

# Imprimir las game_id que faltan en df_dim
print('game_id presentes en df_fact pero faltan en df_dim:')
for game_id in missing_in_dim:
    print(game_id)
# Out:
# game_id presentes en df_fact pero faltan en df_dim:

# %% [markdown]
# ### Observamos que faltan IDS en la tabla de dimensión. Procedemos a arreglarlo

# %%
data.head()
# Out:
#        season_id  team_id_home team_abbreviation_home         team_name_home  \
# 61772       2021    1610612764                    WAS     Washington Wizards
# 61773       2021    1610612762                    UTA              Utah Jazz
# 61774       2021    1610612745                    HOU        Houston Rockets
# 61775       2021    1610612753                    ORL          Orlando Magic
# 61776       2021    1610612760                    OKC  Oklahoma City Thunder
#
#         game_id  game_date matchup_home wl_home  game_minutes  fgm_home  \
# 61772  22000063 2020-12-31  WAS vs. CHI       L           240      42.0
# 61773  22000068 2020-12-31  UTA vs. PHX       L           240      35.0
# 61774  22000065 2020-12-31  HOU vs. SAC       W           240      45.0
# 61775  22000064 2020-12-31  ORL vs. PHI       L           240      33.0
# 61776  22000067 2020-12-31  OKC vs. NOP       L           240      30.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 61772      84.0        0.500       14.0       29.0         0.483      32.0
# 61773      84.0        0.417       12.0       34.0         0.353      13.0
# 61774      86.0        0.523       13.0       36.0         0.361      19.0
# 61775      95.0        0.347        7.0       28.0         0.250      19.0
# 61776      80.0        0.375       15.0       48.0         0.313       5.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 61772      41.0        0.780        9.0       28.0      37.0      27.0
# 61773      19.0        0.684       10.0       36.0      46.0      16.0
# 61774      25.0        0.760       10.0       35.0      45.0      26.0
# 61775      21.0        0.905       10.0       38.0      48.0      17.0
# 61776      15.0        0.333        7.0       33.0      40.0      24.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 61772       8.0       4.0      14.0     27.0     130.0               -3
# 61773       8.0       3.0      14.0     15.0      95.0              -11
# 61774      10.0       6.0      18.0     14.0     122.0                3
# 61775       2.0       5.0      11.0     15.0      92.0              -24
# 61776       6.0       3.0      19.0     20.0      80.0              -33
#
#        team_id_away team_abbreviation_away        team_name_away matchup_away  \
# 61772    1610612741                    CHI         Chicago Bulls    CHI @ WAS
# 61773    1610612756                    PHX          Phoenix Suns    PHX @ UTA
# 61774    1610612758                    SAC      Sacramento Kings    SAC @ HOU
# 61775    1610612755                    PHI    Philadelphia 76ers    PHI @ ORL
# 61776    1610612740                    NOP  New Orleans Pelicans    NOP @ OKC
#
#       wl_away  fgm_away  fga_away  fg_pct_away  fg3m_away  fg3a_away  \
# 61772       W      50.0      92.0        0.543       14.0       36.0
# 61773       W      41.0      84.0        0.488       17.0       33.0
# 61774       L      45.0      96.0        0.469       11.0       33.0
# 61775       W      44.0      91.0        0.484       15.0       33.0
# 61776       W      44.0      91.0        0.484       13.0       36.0
#
#        fg3_pct_away  ftm_away  fta_away  ft_pct_away  oreb_away  dreb_away  \
# 61772         0.389      19.0      25.0        0.760        9.0       35.0
# 61773         0.515       7.0      10.0        0.700        5.0       36.0
# 61774         0.333      18.0      24.0        0.750       14.0       31.0
# 61775         0.455      13.0      15.0        0.867        7.0       47.0
# 61776         0.361      12.0      19.0        0.632       14.0       44.0
#
#        reb_away  ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  \
# 61772      44.0      34.0       9.0       3.0      17.0     27.0     133.0
# 61773      41.0      26.0       5.0       6.0      15.0     17.0     106.0
# 61774      45.0      23.0      11.0       5.0      15.0     21.0     119.0
# 61775      54.0      23.0       7.0      10.0      15.0     23.0     116.0
# 61776      58.0      23.0       9.0       4.0      13.0     16.0     113.0
#
#        plus_minus_away     season_type
# 61772                3  Regular Season
# 61773               11  Regular Season
# 61774               -3  Regular Season
# 61775               24  Regular Season
# 61776               33  Regular Season

# %%
# Seleccionamos solo las columnas 4 y 5 (considerando que los índices empiezan en 0)
df_seleccionado = data.iloc[:, [4, 5]]

# Mostrar el DataFrame resultante
print(df_seleccionado)
# Out:
#         game_id  game_date
# 61772  22000063 2020-12-31
# 61773  22000068 2020-12-31
# 61774  22000065 2020-12-31
# 61775  22000064 2020-12-31
# 61776  22000067 2020-12-31
# ...         ...        ...
# 65692  42200402 2023-06-04
# 65693  42200403 2023-06-07
# 65694  42200404 2023-06-09
# 65695  42200405 2023-06-12
# 65696  32200001 2023-02-19
#
# [3875 rows x 2 columns]

# %%
dim.columns
# Out:
# Index(['game_id', 'game_date', 'attendance'], dtype='object')

# %%
dim_final = dim.iloc[:, [0, 2]]

# Mostrar el DataFrame resultante
print(df_seleccionado)
# Out:
#         game_id  game_date
# 61772  22000063 2020-12-31
# 61773  22000068 2020-12-31
# 61774  22000065 2020-12-31
# 61775  22000064 2020-12-31
# 61776  22000067 2020-12-31
# ...         ...        ...
# 65692  42200402 2023-06-04
# 65693  42200403 2023-06-07
# 65694  42200404 2023-06-09
# 65695  42200405 2023-06-12
# 65696  32200001 2023-02-19
#
# [3875 rows x 2 columns]

# %%
# Realiza el merge en base a la columna 'game_id'
df_combined = pd.merge(df_seleccionado, dim_final, on='game_id', how='left')

# %%
df_combined
# Out:
#        game_id  game_date attendance
# 0     22000063 2020-12-31    15353.0
# 1     22000068 2020-12-31    15353.0
# 2     22000065 2020-12-31    15353.0
# 3     22000064 2020-12-31    15353.0
# 4     22000067 2020-12-31    15353.0
# ...        ...        ...        ...
# 3870  42200402 2023-06-04    19537.0
# 3871  42200403 2023-06-07    20019.0
# 3872  42200404 2023-06-09    20184.0
# 3873  42200405 2023-06-12    19537.0
# 3874  32200001 2023-02-19    17886.0
#
# [3875 rows x 3 columns]

# %%
# Encuentra los game_id en df_fact que no están en df_dim
missing_game_ids = df_seleccionado[~df_seleccionado['game_id'].isin(df_combined['game_id'])]['game_id'].unique()

if len(missing_game_ids) > 0:
    print("Estos game_id están en df_fact pero no en df_dim:")
    print(missing_game_ids)
else:
    print("Todos los game_id en df_fact están presentes en df_dim.")
# Out:
# Todos los game_id en df_fact están presentes en df_dim.

# %%
# PORCENTAJE DE VALORES NULOS
nulos_total = df_combined.isnull().sum()
porcentaje_nulos = (nulos_total / len(data)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': nulos_total,
    'Porcentaje Nulos': porcentaje_nulos
})

print(resumen_nulos)
# Out:
#             Valores Nulos  Porcentaje Nulos
# game_id                 0               0.0
# game_date               0               0.0
# attendance              0               0.0

# %%
df_combined['attendance'] = df_combined['attendance'].fillna(np.median)

# %%
# PORCENTAJE DE VALORES NULOS
nulos_total = df_combined.isnull().sum()
porcentaje_nulos = (nulos_total / len(data)) * 100

resumen_nulos = pd.DataFrame({
    'Valores Nulos': nulos_total,
    'Porcentaje Nulos': porcentaje_nulos
})

print(resumen_nulos)
# Out:
#             Valores Nulos  Porcentaje Nulos
# game_id                 0               0.0
# game_date               0               0.0
# attendance              0               0.0

# %%
df_combined
# Out:
#        game_id  game_date attendance
# 0     22000063 2020-12-31    15353.0
# 1     22000068 2020-12-31    15353.0
# 2     22000065 2020-12-31    15353.0
# 3     22000064 2020-12-31    15353.0
# 4     22000067 2020-12-31    15353.0
# ...        ...        ...        ...
# 3870  42200402 2023-06-04    19537.0
# 3871  42200403 2023-06-07    20019.0
# 3872  42200404 2023-06-09    20184.0
# 3873  42200405 2023-06-12    19537.0
# 3874  32200001 2023-02-19    17886.0
#
# [3875 rows x 3 columns]

# %%
df_combined.dtypes
# Out:
# game_id                int64
# game_date     datetime64[ns]
# attendance            object
# dtype: object

# %%
df_combined['attendance'] = pd.to_numeric(df_combined['attendance'], errors='coerce')

# %%
df_combined.dtypes
# Out:
# game_id                int64
# game_date     datetime64[ns]
# attendance           float64
# dtype: object

# %%
df_combined.head()
# Out:
#     game_id  game_date  attendance
# 0  22000063 2020-12-31     15353.0
# 1  22000068 2020-12-31     15353.0
# 2  22000065 2020-12-31     15353.0
# 3  22000064 2020-12-31     15353.0
# 4  22000067 2020-12-31     15353.0

# %%
df_combined = df_combined.fillna(0)

# %%
# Convierte la columna 'attendance' a int
df_combined['attendance'] = df_combined['attendance'].astype(int)

# %%
np.shape(df_combined)
# Out:
# (3875, 3)

# %%
df_combined.dtypes
# Out:
# game_id                int64
# game_date     datetime64[ns]
# attendance             int64
# dtype: object

# %%
df_combined['attendance'] = df_combined['attendance'].astype('int')

# %%
df_combined.dtypes
# Out:
# game_id                int64
# game_date     datetime64[ns]
# attendance             int64
# dtype: object

# %%
df_combined.to_csv('game_info_filtrado.csv', index=False)

# %% [markdown]
# ### Ahora solo falta verificar que no hay IDS duplicadas en la tabla de dimensión

# %%
duplicados = df_combined.duplicated(keep=False)

# Filtra las filas duplicadas
datos_duplicados = df_combined[duplicados]
print(datos_duplicados)
# Out:
# Empty DataFrame
# Columns: [game_id, game_date, attendance]
# Index: []

# %% [markdown]
# ## Exportamos el dataset ya procesado.

# %%
data.to_csv('game_filtrado.csv', index=False)

# %%
data
# Out:
#        season_id  team_id_home team_abbreviation_home         team_name_home  \
# 61772       2021    1610612764                    WAS     Washington Wizards
# 61773       2021    1610612762                    UTA              Utah Jazz
# 61774       2021    1610612745                    HOU        Houston Rockets
# 61775       2021    1610612753                    ORL          Orlando Magic
# 61776       2021    1610612760                    OKC  Oklahoma City Thunder
# ...          ...           ...                    ...                    ...
# 65692       2023    1610612743                    DEN         Denver Nuggets
# 65693       2023    1610612748                    MIA             Miami Heat
# 65694       2023    1610612748                    MIA             Miami Heat
# 65695       2023    1610612743                    DEN         Denver Nuggets
# 65696       2023    1610616834                    LBN            Team LeBron
#
#         game_id  game_date matchup_home wl_home  game_minutes  fgm_home  \
# 61772  22000063 2020-12-31  WAS vs. CHI       L           240      42.0
# 61773  22000068 2020-12-31  UTA vs. PHX       L           240      35.0
# 61774  22000065 2020-12-31  HOU vs. SAC       W           240      45.0
# 61775  22000064 2020-12-31  ORL vs. PHI       L           240      33.0
# 61776  22000067 2020-12-31  OKC vs. NOP       L           240      30.0
# ...         ...        ...          ...     ...           ...       ...
# 65692  42200402 2023-06-04  DEN vs. MIA       L           240      39.0
# 65693  42200403 2023-06-07  MIA vs. DEN       L           240      34.0
# 65694  42200404 2023-06-09  MIA vs. DEN       L           240      35.0
# 65695  42200405 2023-06-12  DEN vs. MIA       W           240      38.0
# 65696  32200001 2023-02-19  LBN vs. GNS       L           221      79.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# 61772      84.0        0.500       14.0       29.0         0.483      32.0
# 61773      84.0        0.417       12.0       34.0         0.353      13.0
# 61774      86.0        0.523       13.0       36.0         0.361      19.0
# 61775      95.0        0.347        7.0       28.0         0.250      19.0
# 61776      80.0        0.375       15.0       48.0         0.313       5.0
# ...         ...          ...        ...        ...           ...       ...
# 65692      75.0        0.520       11.0       28.0         0.393      19.0
# 65693      92.0        0.370       11.0       35.0         0.314      15.0
# 65694      78.0        0.449        8.0       25.0         0.320      17.0
# 65695      84.0        0.452        5.0       28.0         0.179      13.0
# 65696     132.0        0.598       17.0       60.0         0.283       0.0
#
#        fta_home  ft_pct_home  oreb_home  dreb_home  reb_home  ast_home  \
# 61772      41.0        0.780        9.0       28.0      37.0      27.0
# 61773      19.0        0.684       10.0       36.0      46.0      16.0
# 61774      25.0        0.760       10.0       35.0      45.0      26.0
# 61775      21.0        0.905       10.0       38.0      48.0      17.0
# 61776      15.0        0.333        7.0       33.0      40.0      24.0
# ...         ...          ...        ...        ...       ...       ...
# 65692      22.0        0.864        9.0       29.0      38.0      23.0
# 65693      19.0        0.789       10.0       23.0      33.0      20.0
# 65694      20.0        0.850        8.0       29.0      37.0      23.0
# 65695      23.0        0.565       11.0       46.0      57.0      21.0
# 65696       0.0        0.875       13.0       32.0      45.0      49.0
#
#        stl_home  blk_home  tov_home  pf_home  pts_home  plus_minus_home  \
# 61772       8.0       4.0      14.0     27.0     130.0               -3
# 61773       8.0       3.0      14.0     15.0      95.0              -11
# 61774      10.0       6.0      18.0     14.0     122.0                3
# 61775       2.0       5.0      11.0     15.0      92.0              -24
# 61776       6.0       3.0      19.0     20.0      80.0              -33
# ...         ...       ...       ...      ...       ...              ...
# 65692       7.0       2.0      14.0     21.0     108.0               -3
# 65693       7.0       3.0       4.0     22.0      94.0              -15
# 65694       2.0       3.0      15.0     19.0      95.0              -13
# 65695       6.0       7.0      15.0     13.0      94.0                5
# 65696       7.0       2.0      10.0      5.0     175.0               -9
#
#        team_id_away team_abbreviation_away        team_name_away matchup_away  \
# 61772    1610612741                    CHI         Chicago Bulls    CHI @ WAS
# 61773    1610612756                    PHX          Phoenix Suns    PHX @ UTA
# 61774    1610612758                    SAC      Sacramento Kings    SAC @ HOU
# 61775    1610612755                    PHI    Philadelphia 76ers    PHI @ ORL
# 61776    1610612740                    NOP  New Orleans Pelicans    NOP @ OKC
# ...             ...                    ...                   ...          ...
# 65692    1610612748                    MIA            Miami Heat    MIA @ DEN
# 65693    1610612743                    DEN        Denver Nuggets    DEN @ MIA
# 65694    1610612743                    DEN        Denver Nuggets    DEN @ MIA
# 65695    1610612748                    MIA            Miami Heat    MIA @ DEN
# 65696    1610616833                    GNS          Team Giannis    GNS @ LBN
#
#       wl_away  fgm_away  fga_away  fg_pct_away  fg3m_away  fg3a_away  \
# 61772       W      50.0      92.0        0.543       14.0       36.0
# 61773       W      41.0      84.0        0.488       17.0       33.0
# 61774       L      45.0      96.0        0.469       11.0       33.0
# 61775       W      44.0      91.0        0.484       15.0       33.0
# 61776       W      44.0      91.0        0.484       13.0       36.0
# ...       ...       ...       ...          ...        ...        ...
# 65692       W      38.0      78.0        0.487       17.0       35.0
# 65693       W      41.0      80.0        0.513        5.0       18.0
# 65694       W      39.0      79.0        0.494       14.0       28.0
# 65695       L      33.0      96.0        0.344        9.0       35.0
# 65696       W      76.0     123.0        0.618       29.0       66.0
#
#        fg3_pct_away  ftm_away  fta_away  ft_pct_away  oreb_away  dreb_away  \
# 61772         0.389      19.0      25.0        0.760        9.0       35.0
# 61773         0.515       7.0      10.0        0.700        5.0       36.0
# 61774         0.333      18.0      24.0        0.750       14.0       31.0
# 61775         0.455      13.0      15.0        0.867        7.0       47.0
# 61776         0.361      12.0      19.0        0.632       14.0       44.0
# ...             ...       ...       ...          ...        ...        ...
# 65692         0.486      18.0      20.0        0.900        8.0       23.0
# 65693         0.278      22.0      27.0        0.815       13.0       45.0
# 65694         0.500      16.0      21.0        0.762        5.0       29.0
# 65695         0.257      14.0      16.0        0.875       11.0       33.0
# 65696         0.439       3.0       4.0        0.750       10.0       36.0
#
#        reb_away  ast_away  stl_away  blk_away  tov_away  pf_away  pts_away  \
# 61772      44.0      34.0       9.0       3.0      17.0     27.0     133.0
# 61773      41.0      26.0       5.0       6.0      15.0     17.0     106.0
# 61774      45.0      23.0      11.0       5.0      15.0     21.0     119.0
# 61775      54.0      23.0       7.0      10.0      15.0     23.0     116.0
# 61776      58.0      23.0       9.0       4.0      13.0     16.0     113.0
# ...         ...       ...       ...       ...       ...      ...       ...
# 65692      31.0      28.0       5.0       4.0      11.0     22.0     111.0
# 65693      58.0      28.0       3.0       5.0      14.0     18.0     109.0
# 65694      34.0      26.0      11.0       7.0       8.0     18.0     108.0
# 65695      44.0      18.0       9.0       7.0       8.0     21.0      89.0
# 65696      46.0      43.0       8.0       1.0      12.0      2.0     184.0
#
#        plus_minus_away     season_type
# 61772                3  Regular Season
# 61773               11  Regular Season
# 61774               -3  Regular Season
# 61775               24  Regular Season
# 61776               33  Regular Season
# ...                ...             ...
# 65692                3        Playoffs
# 65693               15        Playoffs
# 65694               13        Playoffs
# 65695               -5        Playoffs
# 65696                9        All-Star
#
# [3875 rows x 53 columns]
